# %%
# !pip install selenium
# !pip install requests
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: selenium in c:\users\shailja tiwari\appdata\roaming\python\python39\site-packages (4.2.0)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\shailja tiwari\appdata\roaming\python\python39\site-packages (from selenium) (0.9.2)
# Requirement already satisfied: urllib3[secure,socks]~=1.26 in c:\programdata\anaconda3\lib\site-packages (from selenium) (1.26.9)
# Requirement already satisfied: trio~=0.17 in c:\users\shailja tiwari\appdata\roaming\python\python39\site-packages (from selenium) (0.21.0)
# Requirement already satisfied: attrs>=19.2.0 in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium) (21.4.0)
# Requirement already satisfied: async-generator>=1.9 in c:\users\shailja tiwari\appdata\roaming\python\python39\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: sortedcontainers in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: sniffio in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: cffi>=1.14 in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.0)
# Requirement already satisfied: idna in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.3)
# Requirement already satisfied: outcome in c:\users\shailja tiwari\appdata\roaming\python\python39\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: pycparser in c:\programdata\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: wsproto>=0.14 in c:\users\shailja tiwari\appdata\roaming\python\python39\site-packages (from trio-websocket~=0.9->selenium) (1.1.0)
# Requirement already satisfied: certifi in c:\programdata\anaconda3\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium) (2021.10.8)
# Requirement already satisfied: pyOpenSSL>=0.14 in c:\programdata\anaconda3\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium) (21.0.0)
# Requirement already satisfied: cryptography>=1.3.4 in c:\programdata\anaconda3\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium) (3.4.8)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\programdata\anaconda3\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: six>=1.5.2 in c:\programdata\anaconda3\lib\site-packages (from pyOpenSSL>=0.14->urllib3[secure,socks]~=1.26->selenium) (1.16.0)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\shailja tiwari\appdata\roaming\python\python39\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.13.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (2.27.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from requests) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests) (3.3)

# %%
# Importing all necessary imports for Beutiful Soup and Selenium library
import pandas as pd
import time
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException, ElementNotInteractableException
import requests
from selenium.common.exceptions import TimeoutException


import selenium 


import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Answer 1

# %%
#IMPORTING chrome driver exe


driver = webdriver.Chrome('chromedriver.exe')

# %%
# Loading url to the chrome driver

url = 'https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos'
driver.get(url)

# %%
count = 0
#creating list for rank, uploader)name, video name, no of views, date of upload
rank = []
video_names = []
video_uploader_name = []
views = []
upload_dates = []


    #RANK ELEMENT
try:
    rank_obj = driver.find_elements_by_xpath('//table[@class="wikitable sortable jquery-tablesorter"]/tbody/tr/td[1]')[:30]
    for i in rank_obj:
        rank.append(i.text)
except NoSuchElementException :
    rank.append('-')
    
    
   #VIDEO NAME ELEMENT
try:
    videoname_obj = driver.find_elements_by_xpath('//table[@class="wikitable sortable jquery-tablesorter"]/tbody/tr/td[2]')[:30]
    for i in videoname_obj:
        video_names.append(i.text.split('[')[0][1:-1])
except NoSuchElementException :
    video_names.append('-')
    
    
    
    #UPLOADER_OF_VIDEO
try:
    uploader_obj = driver.find_elements_by_xpath('//table[@class="wikitable sortable jquery-tablesorter"]/tbody/tr/td[3]')[:30]
    for i in uploader_obj:
        video_uploader_name.append(i.text)
except NoSuchElementException :
    video_uploader_name.append('-')
    
    

    #VIEWS ON THE VIDEOS
try:
    view_obj = driver.find_elements_by_xpath('//table[@class="wikitable sortable jquery-tablesorter"]/tbody/tr/td[4]')[:30]
    for i in view_obj:
        views.append(i.text)
except NoSuchElementException :
    views.append('-')
    
#DATE OF THE VIDEO ELEMENT
try:
    date_obj = driver.find_elements_by_xpath('//table[@class="wikitable sortable jquery-tablesorter"]/tbody/tr/td[5]')[:30]
    for i in date_obj:
        upload_dates.append(i.text)
except NoSuchElementException :
    upload_dates.append('-')

# %%
# creating a diction of all the columns
dict = {'rank':rank, 'video_name':video_names,'uploader':video_uploader_name,'Views in Billions':views,'upload_date':upload_dates}

# %%
# CREATING TABLE / dATA fRAME OF THE DICTIONARY
table = pd.DataFrame(dict)

# %%
table
# Out:
#    rank                                 video_name  \
# 0    1.                           Baby Shark Dance
# 1    2.                                  Despacito
# 2    3.                       Johny Johny Yes Papa
# 3    4.                               Shape of You
# 4    5.                              See You Again
# 5    6.                                  Bath Song
# 6    7.                Phonics Song with Two Words
# 7    8.                                Uptown Funk
# 8    9.  Learning Colors – Colorful Eggs on a Farm
# 9   10.   Masha and the Bear – Recipe for Disaster
# 10  11.                              Gangnam Style
# 11  12.                          Wheels on the Bus
# 12  13.                             Dame Tu Cosita
# 13  14.                                      Sugar
# 14  15.                                       Roar
# 15  16.                             Counting Stars
# 16  17.                                      Sorry
# 17  18.                          Thinking Out Loud
# 18  19.                                     Axel F
# 19  20.                             Girls Like You
# 20  21.                                      Faded
# 21  22.                                 Dark Horse
# 22  23.                        Baa Baa Black Sheep
# 23  24.                                 Let Her Go
# 24  25.                                   Bailando
# 25  26.                                    Lean On
# 26  27.                                    Perfect
# 27  28.                               Shake It Off
# 28  29.           Waka Waka (This Time for Africa)
# 29  30.                                   Mi Gente
#
#                                        uploader Views in Billions  \
# 0   Pinkfong Baby Shark - Kids' Songs & Stories             10.80
# 1                                    Luis Fonsi              7.87
# 2                                   LooLoo Kids              6.37
# 3                                    Ed Sheeran              5.74
# 4                                   Wiz Khalifa              5.54
# 5                    Cocomelon – Nursery Rhymes              5.44
# 6                                     ChuChu TV              4.67
# 7                                   Mark Ronson              4.60
# 8                                   Miroshka TV              4.58
# 9                                    Get Movies              4.50
# 10                                          Psy              4.45
# 11                   Cocomelon – Nursery Rhymes              4.12
# 12                                    El Chombo              3.95
# 13                                     Maroon 5              3.71
# 14                                   Katy Perry              3.60
# 15                                  OneRepublic              3.59
# 16                                Justin Bieber              3.55
# 17                                   Ed Sheeran              3.46
# 18                                   Crazy Frog              3.38
# 19                                     Maroon 5              3.30
# 20                                  Alan Walker              3.29
# 21                                   Katy Perry              3.29
# 22                   Cocomelon – Nursery Rhymes              3.26
# 23                                    Passenger              3.24
# 24                             Enrique Iglesias              3.22
# 25                                  Major Lazer              3.22
# 26                                   Ed Sheeran              3.18
# 27                                 Taylor Swift              3.18
# 28                                      Shakira              3.16
# 29                                     J Balvin              3.09
#
#           upload_date
# 0       June 17, 2016
# 1    January 12, 2017
# 2     October 8, 2016
# 3    January 30, 2017
# 4       April 6, 2015
# 5         May 2, 2018
# 6       March 6, 2014
# 7   November 19, 2014
# 8   February 27, 2018
# 9    January 31, 2012
# 10      July 15, 2012
# 11       May 24, 2018
# 12      April 5, 2018
# 13   January 14, 2015
# 14  September 5, 2013
# 15       May 31, 2013
# 16   October 22, 2015
# 17    October 7, 2014
# 18      June 16, 2009
# 19       May 31, 2018
# 20   December 3, 2015
# 21  February 20, 2014
# 22      June 25, 2018
# 23      July 25, 2012
# 24     April 11, 2014
# 25     March 22, 2015
# 26   November 9, 2017
# 27    August 18, 2014
# 28       June 4, 2010
# 29      June 29, 2017

# %% [markdown]
# ## Answer 4

# %%
driver=webdriver.Chrome("chromedriver.exe")

driver.get( 'http://statisticstimes.com/')

# %%
# selecting heading of econamy
economy=driver.find_element_by_xpath('//*[@id="top"]/div[2]/div[2]/button')
economy.click()

# %%
#Getting subtitle india
india=driver.find_element_by_xpath('//*[@id="top"]/div[2]/div[2]/div/a[3]')
url=india.get_attribute('href')
url
# Out:
# 'https://www.statisticstimes.com/economy/india-statistics.php'

# %%
#getting url for India
driver.get(url)

# %%
#getting India state GDP url
GDP=driver.find_element_by_xpath('/html/body/div[2]/div[2]/div[2]/ul/li[1]/a')
India_GDP=GDP.get_attribute('href')
India_GDP
# Out:
# 'https://www.statisticstimes.com/economy/india/indian-states-gdp.php'

# %%
# getting url of India_GDP url
driver.get(India_GDP)

# %%
#extracting rank data
Rank=[]
try:
    rank=driver.find_elements_by_xpath("//div[@id='table_id_wrapper']/table/tbody/tr/td[1]")
    for i in rank:
        Rank.append(i.text)
except NoSuchElementException:
    Rank.append('-')

# %%
#extracting state data
State=[]
try:
    state=driver.find_elements_by_xpath("//div[@id='table_id_wrapper']/table/tbody/tr/td[2]")
    for i in state:
        State.append(i.text)
except NoSuchElementException:
    State.append('-')

# %%
#extracting GDP current price(18-19) data
GSDP_price18=[]
try:
    gsdp=driver.find_elements_by_xpath("//div[@id='table_id_wrapper']/table/tbody/tr/td[4]")
    for i in gsdp:
        GSDP_price18.append(i.text)
except NoSuchElementException:
    GSDP_price18.append('-')

# %%
#extracting GDP (19-20) current price data
GSDP_price=[]
try:
    gsdp=driver.find_elements_by_xpath("//div[@id='table_id_wrapper']/table/tbody/tr/td[3]")
    for i in gsdp:
        GSDP_price.append(i.text)
except NoSuchElementException:
    GSDP_price.append('-')

# %%
len(GSDP_price)
# Out:
# 33

# %%
#extracting share price(18-19) data
Share=[]
try:
    share=driver.find_elements_by_xpath("//div[@id='table_id_wrapper']/table/tbody/tr/td[5]")
    for i in share:
        Share.append(i.text)
except NoSuchElementException:
    Share.append('-')

# %%
#extracting GDP billion data
GDP_billion=[]
try:
    billion=driver.find_elements_by_xpath("//div[@id='table_id_wrapper']/table/tbody/tr/td[5]")
    for i in billion:
        GDP_billion.append(i.text)
except NoSuchElementException:
    GDP_billion.append('-')

# %%
# creating data frame
df=pd.DataFrame({})

df['Rank']=Rank
df['State']=State
df['GSDP Current Price(19-20)']=GSDP_price
df['GSDP Current Price(18-19)']=GSDP_price18
df['Share(18-19)']=Share
df['GDP($ Billion)']=GDP_billion

# %%
df
# Out:
#    Rank                      State GSDP Current Price(19-20)  \
# 0     1                Maharashtra                         -
# 1     2                 Tamil Nadu                 1,845,853
# 2     3              Uttar Pradesh                 1,687,818
# 3     4                    Gujarat                         -
# 4     5                  Karnataka                 1,631,977
# 5     6                West Bengal                 1,253,832
# 6     7                  Rajasthan                 1,020,989
# 7     8             Andhra Pradesh                   972,782
# 8     9                  Telangana                   969,604
# 9    10             Madhya Pradesh                   906,672
# 10   11                     Kerala                         -
# 11   12                      Delhi                   856,112
# 12   13                    Haryana                   831,610
# 13   14                      Bihar                   611,804
# 14   15                     Punjab                   574,760
# 15   16                     Odisha                   521,275
# 16   17                      Assam                         -
# 17   18               Chhattisgarh                   329,180
# 18   19                  Jharkhand                   328,598
# 19   20                Uttarakhand                         -
# 20   21            Jammu & Kashmir                         -
# 21   22           Himachal Pradesh                   165,472
# 22   23                        Goa                    80,449
# 23   24                    Tripura                    55,984
# 24   25                 Chandigarh                         -
# 25   26                 Puducherry                    38,253
# 26   27                  Meghalaya                    36,572
# 27   28                     Sikkim                    32,496
# 28   29                    Manipur                    31,790
# 29   30                   Nagaland                         -
# 30   31          Arunachal Pradesh                         -
# 31   32                    Mizoram                    26,503
# 32   33  Andaman & Nicobar Islands                         -
#
#    GSDP Current Price(18-19) Share(18-19) GDP($ Billion)
# 0                  2,632,792       13.94%         13.94%
# 1                  1,630,208        8.63%          8.63%
# 2                  1,584,764        8.39%          8.39%
# 3                  1,502,899        7.96%          7.96%
# 4                  1,493,127        7.91%          7.91%
# 5                  1,089,898        5.77%          5.77%
# 6                    942,586        4.99%          4.99%
# 7                    862,957        4.57%          4.57%
# 8                    861,031        4.56%          4.56%
# 9                    809,592        4.29%          4.29%
# 10                   781,653        4.14%          4.14%
# 11                   774,870        4.10%          4.10%
# 12                   734,163        3.89%          3.89%
# 13                   530,363        2.81%          2.81%
# 14                   526,376        2.79%          2.79%
# 15                   487,805        2.58%          2.58%
# 16                   315,881        1.67%          1.67%
# 17                   304,063        1.61%          1.61%
# 18                   297,204        1.57%          1.57%
# 19                   245,895        1.30%          1.30%
# 20                   155,956        0.83%          0.83%
# 21                   153,845        0.81%          0.81%
# 22                    73,170        0.39%          0.39%
# 23                    49,845        0.26%          0.26%
# 24                    42,114        0.22%          0.22%
# 25                    34,433        0.18%          0.18%
# 26                    33,481        0.18%          0.18%
# 27                    28,723        0.15%          0.15%
# 28                    27,870        0.15%          0.15%
# 29                    27,283        0.14%          0.14%
# 30                    24,603        0.13%          0.13%
# 31                    22,287        0.12%          0.12%
# 32                         -            -              -

# %% [markdown]
# ## Answer 8

# %%
# Let's activate and load the chrome browser
driver=webdriver.Chrome('chromedriver.exe')
driver.maximize_window()

# Let's open the URL
driver.get('https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare/')
driver.implicitly_wait(3)

# Let's create an empty lists to store the scraping data
Book_Name=[] 
Author_Name=[] 
Volumes_Sold=[]
Publisher=[] 
Genre=[]

# scrape the data as required
try:
    book = driver.find_elements_by_xpath('//table[@class="in-article sortable"]/tbody/tr/td[2]')
except NoSuchElementException:
    print("Book element N/a")

for i in book:
    Book_Name.append(i.text)
try:
    author = driver.find_elements_by_xpath('//table[@class="in-article sortable"]/tbody/tr/td[3]')
except NoSuchElementException:
    print("Author element N/a")

for i in author:
    Author_Name.append(i.text)
try:
    vol = driver.find_elements_by_xpath('//table[@class="in-article sortable"]/tbody/tr/td[4]')
except NoSuchElementException:
    print("Volumes element N/a")

for i in vol:
    Volumes_Sold.append(i.text)
try:
    pub = driver.find_elements_by_xpath('//table[@class="in-article sortable"]/tbody/tr/td[5]')
except NoSuchElementException:
    print("Publisher element N/a")

for i in pub:
    Publisher.append(i.text)
try:
    gen = driver.find_elements_by_xpath('//table[@class="in-article sortable"]/tbody/tr/td[6]')
except NoSuchElementException:
    print("Genre element N/a")

for i in gen:
    Genre.append(i.text)
    
# Let's create the dataframe from the scraped data
Novel_DF=pd.DataFrame({})
Novel_DF['Book Name']=Book_Name
Novel_DF['Author Name']= Author_Name
Novel_DF['Volumes Sold']=Volumes_Sold
Novel_DF['Publisher']=Publisher
Novel_DF['Genre']=Genre
Novel_DF
# Out:
#                                             Book Name       Author Name  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#    Volumes Sold        Publisher                        Genre
# 0     5,094,805       Transworld  Crime, Thriller & Adventure
# 1     4,475,152       Bloomsbury           Children's Fiction
# 2     4,200,654       Bloomsbury           Children's Fiction
# 3     4,179,479       Bloomsbury           Children's Fiction
# 4     3,758,936     Random House              Romance & Sagas
# ..          ...              ...                          ...
# 95      807,311     Random House   General & Literary Fiction
# 96      794,201          Penguin        Food & Drink: General
# 97      792,187  Scholastic Ltd.          Young Adult Fiction
# 98      791,507            Orion           Biography: General
# 99      791,095          Penguin        Food & Drink: General
#
# [100 rows x 5 columns]

# %% [markdown]
# ## Answer 9

# %%
# Let's activate and load the chrome browser
driver=webdriver.Chrome('chromedriver.exe')
driver.maximize_window()

# Let's open the URL
driver.get('https://www.imdb.com/list/ls095964455/')
driver.implicitly_wait(3)

# Let's create an empty lists to store the scraping data
Name=[]
Year_Span=[] 
Genre=[] 
Run_Time=[] 
Ratings=[] 
Votes=[]

try:
    name = driver.find_elements_by_xpath('//h3[@class="lister-item-header"]/a')
except NoSuchElementException:
    print("Name element N/a")

for i in name:
    Name.append(i.text)
try:
    year = driver.find_elements_by_xpath('//span[@class="lister-item-year text-muted unbold"]')
except NoSuchElementException:
    print("Year span element N/a")

for i in year:
    Year_Span.append(i.text)
try:
    gen = driver.find_elements_by_xpath('//span[@class="genre"]')
except NoSuchElementException:
    print("Genre element N/a")

for i in gen:
    Genre.append(i.text)
try:
    runtime = driver.find_elements_by_xpath('//span[@class="runtime"]')
except NoSuchElementException:
    print("Runtime element N/a")

    
for i in runtime:
    Run_Time.append(i.text)
try:
    ratings = driver.find_elements_by_xpath('//div[@class="ipl-rating-star small"]')
except NoSuchElementException:
    print("Rating element N/a")

for i in ratings:
    Ratings.append(i.text)
try:
    vote = driver.find_elements_by_xpath('//span[@name="nv"]')
except NoSuchElementException:
    print("Vote element N/a")

for i in vote:
    Votes.append(i.text)
    
# Let's create the dataframe from the scraped data
IMDB_DF=pd.DataFrame({})
IMDB_DF['Name']=Name
IMDB_DF['Year Span']= Year_Span
IMDB_DF['Genre']=Genre
IMDB_DF['Run Time']= Run_Time
IMDB_DF['Ratings']=Ratings
IMDB_DF['Votes']=Votes
IMDB_DF
# Out:
#                               Name    Year Span                     Genre  \
# 0                  Game of Thrones  (2011–2019)  Action, Adventure, Drama
# 1                  Stranger Things     (2016– )    Drama, Fantasy, Horror
# 2                 The Walking Dead  (2010–2022)   Drama, Horror, Thriller
# 3                   13 Reasons Why  (2017–2020)  Drama, Mystery, Thriller
# 4                          The 100  (2014–2020)    Drama, Mystery, Sci-Fi
# ..                             ...          ...                       ...
# 95                           Reign  (2013–2017)            Drama, Fantasy
# 96  A Series of Unfortunate Events  (2017–2019)  Adventure, Comedy, Drama
# 97                  Criminal Minds  (2005–2020)     Crime, Drama, Mystery
# 98           Scream: The TV Series  (2015–2019)      Comedy, Crime, Drama
# 99      The Haunting of Hill House       (2018)    Drama, Horror, Mystery
#
#    Run Time Ratings      Votes
# 0    57 min     9.2  1,998,326
# 1    51 min     8.7  1,046,319
# 2    44 min     8.2    950,938
# 3    60 min     7.5    284,212
# 4    43 min     7.6    244,004
# ..      ...     ...        ...
# 95   42 min     7.4     48,938
# 96   50 min     7.8     59,649
# 97   42 min     8.1    190,888
# 98   45 min     7.1     40,377
# 99  572 min     8.6    229,411
#
# [100 rows x 6 columns]

# %% [markdown]
# ## Answer 10

# %%
# Let's activate and load the chrome browser
driver=webdriver.Chrome('chromedriver.exe')
driver.maximize_window()

# Let's open the URL
driver.get('https://archive.ics.uci.edu/')
driver.implicitly_wait(3)

# Let's navigate to view all dataset
try:
    dataset=driver.find_element_by_xpath("//span[@class='normal']/b/a")
    driver.get(dataset.get_attribute('href'))
except NoSuchElementException:
    print("Span class normal not avlbl")
# Let's create an empty lists to store the scraping data
Dataset_Name=[] 
Data_Type=[]
Task=[] 
Attribute_Type=[] 
No_of_Instances=[] 
No_of_Attribute=[] 
Year=[]
try:
    name = driver.find_elements_by_xpath('//table[@border="1"]/tbody/tr[2]/td/table/tbody/tr/td[2]/p/b/a')
except NoSuchElementException:
    print("Name element N/a")

for i in name:
    Dataset_Name.append(i.text)
try:
    names = driver.find_elements_by_xpath('//tr[@bgcolor="DDEEFF"]/td/table/tbody/tr/td[2]/p/b/a')
except NoSuchElementException:
    print("Names element N/a")

for i in names:
    Dataset_Name.append(i.text)
try:
    datatype = driver.find_elements_by_xpath('//table[@border="1"]/tbody/tr[2]/td[2]/p')
except NoSuchElementException:
    print("Data Type element N/a")

for i in datatype:
    Data_Type.append(i.text)

try:
    task = driver.find_elements_by_xpath('//table[@border="1"]/tbody/tr[2]/td[3]/p')
except NoSuchElementException:
    print("Task element N/a")

for i in task:
    Task.append(i.text)

try:    
    att = driver.find_elements_by_xpath('//table[@border="1"]/tbody/tr[2]/td[4]/p')
except NoSuchElementException:
    print("Attribute element N/a")

for i in att:
    Attribute_Type.append(i.text)

try:    
    ins = driver.find_elements_by_xpath('//table[@border="1"]/tbody/tr[2]/td[5]/p')
except NoSuchElementException:
    print("Instances element N/a")
    
for i in ins:
    No_of_Instances.append(i.text)

try:    
    no_of_att = driver.find_elements_by_xpath('//table[@border="1"]/tbody/tr[2]/td[6]/p')
except NoSuchElementException:
    print("Attribute element N/a")
    
for i in no_of_att:
    No_of_Attribute.append(i.text)
try:
    year = driver.find_elements_by_xpath('//table[@border="1"]/tbody/tr[2]/td[7]/p')
except NoSuchElementException:
    print("Year element N/a")

for i in year:
    Year.append(i.text)

try:
    datatype = driver.find_elements_by_xpath('//tr[@bgcolor="DDEEFF"]/td[2]/p')
except NoSuchElementException:
    print("Datatype element N/a")

for i in datatype:
    Data_Type.append(i.text)

try:
    tsk = driver.find_elements_by_xpath('//tr[@bgcolor="DDEEFF"]/td[3]/p')
except NoSuchElementException:
    print("Task element N/a")

for i in tsk:
    Task.append(i.text)
try:
    attr = driver.find_elements_by_xpath('//tr[@bgcolor="DDEEFF"]/td[4]/p')
except NoSuchElementException:
    print("Attribute element N/a")

for i in attr:
    Attribute_Type.append(i.text)
try:
    noi = driver.find_elements_by_xpath('//tr[@bgcolor="DDEEFF"]/td[5]/p')
except NoSuchElementException:
    print("Instance element N/a")

for i in noi:
    No_of_Instances.append(i.text)
try:
    noa = driver.find_elements_by_xpath('//tr[@bgcolor="DDEEFF"]/td[6]/p')
except NoSuchElementException:
    print("Number of Attribute element N/a")

for i in noa:
    No_of_Attribute.append(i.text)
try:
    yr = driver.find_elements_by_xpath('//tr[@bgcolor="DDEEFF"]/td[7]/p')
except NoSuchElementException:
    print("Year element N/a")

for i in yr:
    Year.append(i.text)
    
# Let's create the dataframe from the scraped data
UCI_DF=pd.DataFrame({})
UCI_DF['Dataset Name']=Dataset_Name 
UCI_DF['Data Type']=Data_Type
UCI_DF['Task']=Task
UCI_DF['Attribute Type']=Attribute_Type
UCI_DF['No of Instances']=No_of_Instances
UCI_DF['No of Attribute']= No_of_Attribute
UCI_DF['Year']=Year
UCI_DF
# Out:
#                                           Dataset Name  \
# 0                                              Abalone
# 1                                                Adult
# 2                         Anonymous Microsoft Web Data
# 3                                Artificial Characters
# 4                             Audiology (Standardized)
# ..                                                 ...
# 307  Image Recognition Task Execution Times in Mobi...
# 308                                           REJAFADA
# 309  Influenza outbreak event prediction via Twitte...
# 310                      Maternal Health Risk Data Set
# 311  Image Recognition Task Execution Times in Mobi...
#
#                                 Data Type                  Task  \
# 0                           Multivariate        Classification
# 1                           Multivariate        Classification
# 2                                          Recommender-Systems
# 3                           Multivariate        Classification
# 4                           Multivariate        Classification
# ..                                    ...                   ...
# 307  Univariate, Sequential, Time-Series            Regression
# 308                         Multivariate        Classification
# 309                         Multivariate        Classification
# 310                                             Classification
# 311                           Univariate            Regression
#
#                   Attribute Type No of Instances No of Attribute   Year
# 0    Categorical, Integer, Real            4177               8   1995
# 1          Categorical, Integer           48842              14   1996
# 2                   Categorical           37711             294   1998
# 3    Categorical, Integer, Real            6000               7   1992
# 4                   Categorical             226              69   1992
# ..                           ...             ...             ...    ...
# 307                        Real            4000               2   2020
# 308                     Integer            1996            6826   2020
# 309               Integer, Real           75840             525   2020
# 310                                        1014               7   2020
# 311                        Real            4000               2   2021
#
# [312 rows x 7 columns]

# %% [markdown]
# ## Answer 3

# %%
driver=webdriver.Chrome('chromedriver.exe')


# Let's open the URL
driver.get('https://www.guru99.com/')

# %%
search_job = driver.find_element_by_xpath("//input")
search_job
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="65ca3e7f9514a229959a32c6c392f71c", element="c58b565a-5e62-446f-988f-8266720c4819")>

# %%
name_tags=[]

# %%
for i in range(10):
    for j in driver.find_elements_by_xpath("//h4"):
        name_tags.append(j.text)
    time.sleep(5)

# %%
name_tags
# Out:
# ['Search for your Favorite Course',
#  'TESTING',
#  'LIVE PROJECTS',
#  'DEFECT TOOLS',
#  'ENTERPRISE TESTING',
#  'PERFORMANCE TESTING',
#  'SAP',
#  'BIG DATA',
#  'AI',
#  'WEB',
#  'TEST MANAGEMENT',
#  'MUST LEARN!',
#  'DATABASE',
#  'PractiTest',
#  'APIs',
#  'Kobiton',
#  'ACCELQ',
#  'testRigor',
#  '3CX Live Chat',
#  'Python',
#  'Ethical Hacking',
#  'Java',
#  'Big Data',
#  'Linux',
#  'JIRA',
#  'Search for your Favorite Course',
#  'TESTING',
#  'LIVE PROJECTS',
#  'DEFECT TOOLS',
#  'ENTERPRISE TESTING',
#  'PERFORMANCE TESTING',
#  'SAP',
#  'BIG DATA',
#  'AI',
#  'WEB',
#  'TEST MANAGEMENT',
#  'MUST LEARN!',
#  'DATABASE',
#  'PractiTest',
#  'APIs',
#  'Kobiton',
#  'ACCELQ',
#  'testRigor',
#  '3CX Live Chat',
#  'Python',
#  'Ethical Hacking',
#  'Java',
#  'Big Data',
#  'Linux',
#  'JIRA',
#  'Search for your Favorite Course',
#  'TESTING',
#  'LIVE PROJECTS',
#  'DEFECT TOOLS',
#  'ENTERPRISE TESTING',
#  'PERFORMANCE TESTING',
#  'SAP',
#  'BIG DATA',
#  'AI',
#  'WEB',
#  'TEST MANAGEMENT',
#  'MUST LEARN!',
#  'DATABASE',
#  'PractiTest',
#  'APIs',
#  'Kobiton',
#  'ACCELQ',
#  'testRigor',
#  '3CX Live Chat',
#  'Python',
#  'Ethical Hacking',
#  'Java',
#  'Big Data',
#  'Linux',
#  'JIRA',
#  'Search for your Favorite Course',
#  'TESTING',
#  'LIVE PROJECTS',
#  'DEFECT TOOLS',
#  'ENTERPRISE TESTING',
#  'PERFORMANCE TESTING',
#  'SAP',
#  'BIG DATA',
#  'AI',
#  'WEB',
#  'TEST MANAGEMENT',
#  'MUST LEARN!',
#  'DATABASE',
#  'PractiTest',
#  'APIs',
#  'Kobiton',
#  'ACCELQ',
#  'testRigor',
#  '3CX Live Chat',
#  'Python',
#  'Ethical Hacking',
#  'Java',
#  'Big Data',
#  'Linux',
#  'JIRA',
#  'Search for your Favorite Course',
#  'TESTING',
#  'LIVE PROJECTS',
#  'DEFECT TOOLS',
#  'ENTERPRISE TESTING',
#  'PERFORMANCE TESTING',
#  'SAP',
#  'BIG DATA',
#  'AI',
#  'WEB',
#  'TEST MANAGEMENT',
#  'MUST LEARN!',
#  'DATABASE',
#  'PractiTest',
#  'APIs',
#  'Kobiton',
#  'ACCELQ',
#  'testRigor',
#  '3CX Live Chat',
#  'Python',
#  'Ethical Hacking',
#  'Java',
#  'Big Data',
#  'Linux',
#  'JIRA',
#  'Search for your Favorite Course',
#  'TESTING',
#  'LIVE PROJECTS',
#  'DEFECT TOOLS',
#  'ENTERPRISE TESTING',
#  'PERFORMANCE TESTING',
#  'SAP',
#  'BIG DATA',
#  'AI',
#  'WEB',
#  'TEST MANAGEMENT',
#  'MUST LEARN!',
#  'DATABASE',
#  'PractiTest',
#  'APIs',
#  'Kobiton',
#  'ACCELQ',
#  'testRigor',
#  '3CX Live Chat',
#  'Python',
#  'Ethical Hacking',
#  'Java',
#  'Big Data',
#  'Linux',
#  'JIRA',
#  'Search for your Favorite Course',
#  'TESTING',
#  'LIVE PROJECTS',
#  'DEFECT TOOLS',
#  'ENTERPRISE TESTING',
#  'PERFORMANCE TESTING',
#  'SAP',
#  'BIG DATA',
#  'AI',
#  'WEB',
#  'TEST MANAGEMENT',
#  'MUST LEARN!',
#  'DATABASE',
#  'PractiTest',
#  'APIs',
#  'Kobiton',
#  'ACCELQ',
#  'testRigor',
#  '3CX Live Chat',
#  'Python',
#  'Ethical Hacking',
#  'Java',
#  'Big Data',
#  'Linux',
#  'JIRA',
#  'Search for your Favorite Course',
#  'TESTING',
#  'LIVE PROJECTS',
#  'DEFECT TOOLS',
#  'ENTERPRISE TESTING',
#  'PERFORMANCE TESTING',
#  'SAP',
#  'BIG DATA',
#  'AI',
#  'WEB',
#  'TEST MANAGEMENT',
#  'MUST LEARN!',
#  'DATABASE',
#  'PractiTest',
#  'APIs',
#  'Kobiton',
#  'ACCELQ',
#  'testRigor',
#  '3CX Live Chat',
#  'Python',
#  'Ethical Hacking',
#  'Java',
#  'Big Data',
#  'Linux',
#  'JIRA',
#  'Search for your Favorite Course',
#  'TESTING',
#  'LIVE PROJECTS',
#  'DEFECT TOOLS',
#  'ENTERPRISE TESTING',
#  'PERFORMANCE TESTING',
#  'SAP',
#  'BIG DATA',
#  'AI',
#  'WEB',
#  'TEST MANAGEMENT',
#  'MUST LEARN!',
#  'DATABASE',
#  'PractiTest',
#  'APIs',
#  'Kobiton',
#  'ACCELQ',
#  'testRigor',
#  '3CX Live Chat',
#  'Python',
#  'Ethical Hacking',
#  'Java',
#  'Big Data',
#  'Linux',
#  'JIRA',
#  'Search for your Favorite Course',
#  'TESTING',
#  'LIVE PROJECTS',
#  'DEFECT TOOLS',
#  'ENTERPRISE TESTING',
#  'PERFORMANCE TESTING',
#  'SAP',
#  'BIG DATA',
#  'AI',
#  'WEB',
#  'TEST MANAGEMENT',
#  'MUST LEARN!',
#  'DATABASE',
#  'PractiTest',
#  'APIs',
#  'Kobiton',
#  'ACCELQ',
#  'testRigor',
#  '3CX Live Chat',
#  'Python',
#  'Ethical Hacking',
#  'Java',
#  'Big Data',
#  'Linux',
#  'JIRA']

# %%
description_tags=[]

# %%
for i in range(10):
    for j in driver.find_elements_by_xpath("//h3"):
        description_tags.append(j.text)
    time.sleep(5)

# %%
description_tags
# Out:
# ['Guru99 is totally new kind of learning experience.',
#  'Guru99 is totally new kind of learning experience.',
#  'Guru99 is totally new kind of learning experience.',
#  'Guru99 is totally new kind of learning experience.',
#  'Guru99 is totally new kind of learning experience.',
#  'Guru99 is totally new kind of learning experience.',
#  'Guru99 is totally new kind of learning experience.',
#  'Guru99 is totally new kind of learning experience.',
#  'Guru99 is totally new kind of learning experience.',
#  'Guru99 is totally new kind of learning experience.']

# %%
for i in range(10):
    for j in driver.find_elements_by_xpath("//div[@class='span12']"):
        description_tags.append(j.text)
    time.sleep(5)

# %%
description_tags
# Out:
# ['Guru99 is totally new kind of learning experience.',
#  'Guru99 is totally new kind of learning experience.',
#  'Guru99 is totally new kind of learning experience.',
#  'Guru99 is totally new kind of learning experience.',
#  'Guru99 is totally new kind of learning experience.',
#  'Guru99 is totally new kind of learning experience.',
#  'Guru99 is totally new kind of learning experience.',
#  'Guru99 is totally new kind of learning experience.',
#  'Guru99 is totally new kind of learning experience.',
#  'Guru99 is totally new kind of learning experience.']

# %% [markdown]
# ## Answer 2

# %%
driver=webdriver.Chrome("chromedriver.exe")
driver.get('https://www.bcci.tv/')

# %%
search_job = driver.find_element_by_xpath("//a")
search_job
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="fa84747ca0d41018269230b2116c4566", element="6e7fcd1b-dec7-40d0-884a-5dfdd39da18e")>

# %%
matchtitle_tags=[]

# %%
for i in range(10):
    for j in driver.find_elements_by_xpath("//span[@class='ng-binding']"):
        matchtitle_tags.append(j.text)
    time.sleep(5)

# %%
matchtitle_tags
# Out:
# ['INDIA WOMEN TOUR OF SRI LANKA T20 SERIES 2022',
#  'INDIA WOMEN TOUR OF SRI LANKA T20 SERIES 2022',
#  'INDIA TOUR OF IRELAND T20 SERIES 2022',
#  'INDIA WOMEN TOUR OF SRI LANKA T20 SERIES 2022',
#  'INDIA TOUR OF IRELAND T20 SERIES 2022',
#  'INDIA WOMEN TOUR OF SRI LANKA ODI SERIES 2022',
#  'INDIA TOUR OF ENGLAND TEST SERIES 2021',
#  'INDIA WOMEN TOUR OF SRI LANKA ODI SERIES 2022',
#  'INDIA WOMEN TOUR OF SRI LANKA T20 SERIES 2022',
#  'INDIA WOMEN TOUR OF SRI LANKA T20 SERIES 2022',
#  'INDIA TOUR OF IRELAND T20 SERIES 2022',
#  'INDIA WOMEN TOUR OF SRI LANKA T20 SERIES 2022',
#  'INDIA TOUR OF IRELAND T20 SERIES 2022',
#  'INDIA WOMEN TOUR OF SRI LANKA ODI SERIES 2022',
#  'INDIA TOUR OF ENGLAND TEST SERIES 2021',
#  'INDIA WOMEN TOUR OF SRI LANKA ODI SERIES 2022',
#  'INDIA WOMEN TOUR OF SRI LANKA T20 SERIES 2022',
#  'INDIA WOMEN TOUR OF SRI LANKA T20 SERIES 2022',
#  'INDIA TOUR OF IRELAND T20 SERIES 2022',
#  'INDIA WOMEN TOUR OF SRI LANKA T20 SERIES 2022',
#  'INDIA TOUR OF IRELAND T20 SERIES 2022',
#  'INDIA WOMEN TOUR OF SRI LANKA ODI SERIES 2022',
#  'INDIA TOUR OF ENGLAND TEST SERIES 2021',
#  'INDIA WOMEN TOUR OF SRI LANKA ODI SERIES 2022',
#  'INDIA WOMEN TOUR OF SRI LANKA T20 SERIES 2022',
#  'INDIA WOMEN TOUR OF SRI LANKA T20 SERIES 2022',
#  'INDIA TOUR OF IRELAND T20 SERIES 2022',
#  'INDIA WOMEN TOUR OF SRI LANKA T20 SERIES 2022',
#  'INDIA TOUR OF IRELAND T20 SERIES 2022',
#  'INDIA WOMEN TOUR OF SRI LANKA ODI SERIES 2022',
#  'INDIA TOUR OF ENGLAND TEST SERIES 2021',
#  'INDIA WOMEN TOUR OF SRI LANKA ODI SERIES 2022',
#  'INDIA WOMEN TOUR OF SRI LANKA T20 SERIES 2022',
#  'INDIA WOMEN TOUR OF SRI LANKA T20 SERIES 2022',
#  'INDIA TOUR OF IRELAND T20 SERIES 2022',
#  'INDIA WOMEN TOUR OF SRI LANKA T20 SERIES 2022',
#  'INDIA TOUR OF IRELAND T20 SERIES 2022',
#  'INDIA WOMEN TOUR OF SRI LANKA ODI SERIES 2022',
#  'INDIA TOUR OF ENGLAND TEST SERIES 2021',
#  'INDIA WOMEN TOUR OF SRI LANKA ODI SERIES 2022',
#  'INDIA WOMEN TOUR OF SRI LANKA T20 SERIES 2022',
#  'INDIA WOMEN TOUR OF SRI LANKA T20 SERIES 2022',
#  'INDIA TOUR OF IRELAND T20 SERIES 2022',
#  'INDIA WOMEN TOUR OF SRI LANKA T20 SERIES 2022',
#  'INDIA TOUR OF IRELAND T20 SERIES 2022',
#  'INDIA WOMEN TOUR OF SRI LANKA ODI SERIES 2022',
#  'INDIA TOUR OF ENGLAND TEST SERIES 2021',
#  'INDIA WOMEN TOUR OF SRI LANKA ODI SERIES 2022',
#  'INDIA WOMEN TOUR OF SRI LANKA T20 SERIES 2022',
#  'INDIA WOMEN TOUR OF SRI LANKA T20 SERIES 2022',
#  'INDIA TOUR OF IRELAND T20 SERIES 2022',
#  'INDIA WOMEN TOUR OF SRI LANKA T20 SERIES 2022',
#  'INDIA TOUR OF IRELAND T20 SERIES 2022',
#  'INDIA WOMEN TOUR OF SRI LANKA ODI SERIES 2022',
#  'INDIA TOUR OF ENGLAND TEST SERIES 2021',
#  'INDIA WOMEN TOUR OF SRI LANKA ODI SERIES 2022',
#  'INDIA WOMEN TOUR OF SRI LANKA T20 SERIES 2022',
#  'INDIA WOMEN TOUR OF SRI LANKA T20 SERIES 2022',
#  'INDIA TOUR OF IRELAND T20 SERIES 2022',
#  'INDIA WOMEN TOUR OF SRI LANKA T20 SERIES 2022',
#  'INDIA TOUR OF IRELAND T20 SERIES 2022',
#  'INDIA WOMEN TOUR OF SRI LANKA ODI SERIES 2022',
#  'INDIA TOUR OF ENGLAND TEST SERIES 2021',
#  'INDIA WOMEN TOUR OF SRI LANKA ODI SERIES 2022',
#  'INDIA WOMEN TOUR OF SRI LANKA T20 SERIES 2022',
#  'INDIA WOMEN TOUR OF SRI LANKA T20 SERIES 2022',
#  'INDIA TOUR OF IRELAND T20 SERIES 2022',
#  'INDIA WOMEN TOUR OF SRI LANKA T20 SERIES 2022',
#  'INDIA TOUR OF IRELAND T20 SERIES 2022',
#  'INDIA WOMEN TOUR OF SRI LANKA ODI SERIES 2022',
#  'INDIA TOUR OF ENGLAND TEST SERIES 2021',
#  'INDIA WOMEN TOUR OF SRI LANKA ODI SERIES 2022',
#  'INDIA WOMEN TOUR OF SRI LANKA T20 SERIES 2022',
#  'INDIA WOMEN TOUR OF SRI LANKA T20 SERIES 2022',
#  'INDIA TOUR OF IRELAND T20 SERIES 2022',
#  'INDIA WOMEN TOUR OF SRI LANKA T20 SERIES 2022',
#  'INDIA TOUR OF IRELAND T20 SERIES 2022',
#  'INDIA WOMEN TOUR OF SRI LANKA ODI SERIES 2022',
#  'INDIA TOUR OF ENGLAND TEST SERIES 2021',
#  'INDIA WOMEN TOUR OF SRI LANKA ODI SERIES 2022']

# %%
series_tags=[]

# %%
for i in range(10):
    for j in driver.find_elements_by_xpath("//span[@class='matchOrderText ng-binding ng-scope']"):
        series_tags.append(j.text)
    time.sleep(5)

# %%
series_tags
# Out:
# ['Sri Lanka Women\nvs\nIndia Women',
#  'Sri Lanka Women\nvs\nIndia Women',
#  'Ireland\nvs\nIndia',
#  'Sri Lanka Women\nvs\nIndia Women',
#  'Ireland\nvs\nIndia',
#  'Sri Lanka Women\nvs\nIndia Women',
#  'England\nvs\nIndia',
#  'Sri Lanka Women\nvs\nIndia Women',
#  'Sri Lanka Women\nvs\nIndia Women',
#  'Sri Lanka Women\nvs\nIndia Women',
#  'Ireland\nvs\nIndia',
#  'Sri Lanka Women\nvs\nIndia Women',
#  'Ireland\nvs\nIndia',
#  'Sri Lanka Women\nvs\nIndia Women',
#  'England\nvs\nIndia',
#  'Sri Lanka Women\nvs\nIndia Women',
#  'Sri Lanka Women\nvs\nIndia Women',
#  'Sri Lanka Women\nvs\nIndia Women',
#  'Ireland\nvs\nIndia',
#  'Sri Lanka Women\nvs\nIndia Women',
#  'Ireland\nvs\nIndia',
#  'Sri Lanka Women\nvs\nIndia Women',
#  'England\nvs\nIndia',
#  'Sri Lanka Women\nvs\nIndia Women',
#  'Sri Lanka Women\nvs\nIndia Women',
#  'Sri Lanka Women\nvs\nIndia Women',
#  'Ireland\nvs\nIndia',
#  'Sri Lanka Women\nvs\nIndia Women',
#  'Ireland\nvs\nIndia',
#  'Sri Lanka Women\nvs\nIndia Women',
#  'England\nvs\nIndia',
#  'Sri Lanka Women\nvs\nIndia Women',
#  'Sri Lanka Women\nvs\nIndia Women',
#  'Sri Lanka Women\nvs\nIndia Women',
#  'Ireland\nvs\nIndia',
#  'Sri Lanka Women\nvs\nIndia Women',
#  'Ireland\nvs\nIndia',
#  'Sri Lanka Women\nvs\nIndia Women',
#  'England\nvs\nIndia',
#  'Sri Lanka Women\nvs\nIndia Women',
#  'Sri Lanka Women\nvs\nIndia Women',
#  'Sri Lanka Women\nvs\nIndia Women',
#  'Ireland\nvs\nIndia',
#  'Sri Lanka Women\nvs\nIndia Women',
#  'Ireland\nvs\nIndia',
#  'Sri Lanka Women\nvs\nIndia Women',
#  'England\nvs\nIndia',
#  'Sri Lanka Women\nvs\nIndia Women',
#  'Sri Lanka Women\nvs\nIndia Women',
#  'Sri Lanka Women\nvs\nIndia Women',
#  'Ireland\nvs\nIndia',
#  'Sri Lanka Women\nvs\nIndia Women',
#  'Ireland\nvs\nIndia',
#  'Sri Lanka Women\nvs\nIndia Women',
#  'England\nvs\nIndia',
#  'Sri Lanka Women\nvs\nIndia Women',
#  'Sri Lanka Women\nvs\nIndia Women',
#  'Sri Lanka Women\nvs\nIndia Women',
#  'Ireland\nvs\nIndia',
#  'Sri Lanka Women\nvs\nIndia Women',
#  'Ireland\nvs\nIndia',
#  'Sri Lanka Women\nvs\nIndia Women',
#  'England\nvs\nIndia',
#  'Sri Lanka Women\nvs\nIndia Women',
#  'Sri Lanka Women\nvs\nIndia Women',
#  'Sri Lanka Women\nvs\nIndia Women',
#  'Ireland\nvs\nIndia',
#  'Sri Lanka Women\nvs\nIndia Women',
#  'Ireland\nvs\nIndia',
#  'Sri Lanka Women\nvs\nIndia Women',
#  'England\nvs\nIndia',
#  'Sri Lanka Women\nvs\nIndia Women',
#  'Sri Lanka Women\nvs\nIndia Women',
#  'Sri Lanka Women\nvs\nIndia Women',
#  'Ireland\nvs\nIndia',
#  'Sri Lanka Women\nvs\nIndia Women',
#  'Ireland\nvs\nIndia',
#  'Sri Lanka Women\nvs\nIndia Women',
#  'England\nvs\nIndia',
#  'Sri Lanka Women\nvs\nIndia Women',
#  '1st T20I -',
#  '2nd T20I -',
#  '1st T20I -',
#  '3rd T20I -',
#  '2nd T20I -',
#  '1st ODI -',
#  '5th Test -',
#  '2nd ODI -',
#  '1st T20I -',
#  '2nd T20I -',
#  '1st T20I -',
#  '3rd T20I -',
#  '2nd T20I -',
#  '1st ODI -',
#  '5th Test -',
#  '2nd ODI -',
#  '1st T20I -',
#  '2nd T20I -',
#  '1st T20I -',
#  '3rd T20I -',
#  '2nd T20I -',
#  '1st ODI -',
#  '5th Test -',
#  '2nd ODI -',
#  '1st T20I -',
#  '2nd T20I -',
#  '1st T20I -',
#  '3rd T20I -',
#  '2nd T20I -',
#  '1st ODI -',
#  '5th Test -',
#  '2nd ODI -',
#  '1st T20I -',
#  '2nd T20I -',
#  '1st T20I -',
#  '3rd T20I -',
#  '2nd T20I -',
#  '1st ODI -',
#  '5th Test -',
#  '2nd ODI -',
#  '1st T20I -',
#  '2nd T20I -',
#  '1st T20I -',
#  '3rd T20I -',
#  '2nd T20I -',
#  '1st ODI -',
#  '5th Test -',
#  '2nd ODI -',
#  '1st T20I -',
#  '2nd T20I -',
#  '1st T20I -',
#  '3rd T20I -',
#  '2nd T20I -',
#  '1st ODI -',
#  '5th Test -',
#  '2nd ODI -',
#  '1st T20I -',
#  '2nd T20I -',
#  '1st T20I -',
#  '3rd T20I -',
#  '2nd T20I -',
#  '1st ODI -',
#  '5th Test -',
#  '2nd ODI -',
#  '1st T20I -',
#  '2nd T20I -',
#  '1st T20I -',
#  '3rd T20I -',
#  '2nd T20I -',
#  '1st ODI -',
#  '5th Test -',
#  '2nd ODI -',
#  '1st T20I -',
#  '2nd T20I -',
#  '1st T20I -',
#  '3rd T20I -',
#  '2nd T20I -',
#  '1st ODI -',
#  '5th Test -',
#  '2nd ODI -']

# %%
place_tags=[]

for i in range(10):
    for j in driver.find_elements_by_xpath("//span[@class='ng-binding ng-scope']"):
        place_tags.append(j.text)
    time.sleep(5)
    
place_tags
# Out:
# ['Rangiri Dambulla International Stadium,',
#  'Rangiri Dambulla International Stadium,',
#  'The Village,',
#  'Rangiri Dambulla International Stadium,',
#  'The Village,',
#  'Pallekele International Cricket Stadium,',
#  'Edgbaston,',
#  'Pallekele International Cricket Stadium,',
#  'Rangiri Dambulla International Stadium,',
#  'Rangiri Dambulla International Stadium,',
#  'The Village,',
#  'Rangiri Dambulla International Stadium,',
#  'The Village,',
#  'Pallekele International Cricket Stadium,',
#  'Edgbaston,',
#  'Pallekele International Cricket Stadium,',
#  'Rangiri Dambulla International Stadium,',
#  'Rangiri Dambulla International Stadium,',
#  'The Village,',
#  'Rangiri Dambulla International Stadium,',
#  'The Village,',
#  'Pallekele International Cricket Stadium,',
#  'Edgbaston,',
#  'Pallekele International Cricket Stadium,',
#  'Rangiri Dambulla International Stadium,',
#  'Rangiri Dambulla International Stadium,',
#  'The Village,',
#  'Rangiri Dambulla International Stadium,',
#  'The Village,',
#  'Pallekele International Cricket Stadium,',
#  'Edgbaston,',
#  'Pallekele International Cricket Stadium,',
#  'Rangiri Dambulla International Stadium,',
#  'Rangiri Dambulla International Stadium,',
#  'The Village,',
#  'Rangiri Dambulla International Stadium,',
#  'The Village,',
#  'Pallekele International Cricket Stadium,',
#  'Edgbaston,',
#  'Pallekele International Cricket Stadium,',
#  'Rangiri Dambulla International Stadium,',
#  'Rangiri Dambulla International Stadium,',
#  'The Village,',
#  'Rangiri Dambulla International Stadium,',
#  'The Village,',
#  'Pallekele International Cricket Stadium,',
#  'Edgbaston,',
#  'Pallekele International Cricket Stadium,',
#  'Rangiri Dambulla International Stadium,',
#  'Rangiri Dambulla International Stadium,',
#  'The Village,',
#  'Rangiri Dambulla International Stadium,',
#  'The Village,',
#  'Pallekele International Cricket Stadium,',
#  'Edgbaston,',
#  'Pallekele International Cricket Stadium,',
#  'Rangiri Dambulla International Stadium,',
#  'Rangiri Dambulla International Stadium,',
#  'The Village,',
#  'Rangiri Dambulla International Stadium,',
#  'The Village,',
#  'Pallekele International Cricket Stadium,',
#  'Edgbaston,',
#  'Pallekele International Cricket Stadium,',
#  'Rangiri Dambulla International Stadium,',
#  'Rangiri Dambulla International Stadium,',
#  'The Village,',
#  'Rangiri Dambulla International Stadium,',
#  'The Village,',
#  'Pallekele International Cricket Stadium,',
#  'Edgbaston,',
#  'Pallekele International Cricket Stadium,',
#  'Rangiri Dambulla International Stadium,',
#  'Rangiri Dambulla International Stadium,',
#  'The Village,',
#  'Rangiri Dambulla International Stadium,',
#  'The Village,',
#  'Pallekele International Cricket Stadium,',
#  'Edgbaston,',
#  'Pallekele International Cricket Stadium,']

# %%
date_tags=[]
for i in range(10):
    for j in driver.find_elements_by_xpath("//div[@class='match-top-info d-flex align-items-center justify-content-between']"):
        date_tags.append(j.text)
    time.sleep(5)
date_tags
# Out:
# ['23 JUN 2022\n2:30 PM IST',
#  '25 JUN 2022\n2:30 PM IST',
#  '26 JUN 2022\n9:00 PM IST',
#  '27 JUN 2022\n2:30 PM IST',
#  '28 JUN 2022\n9:00 PM IST',
#  '1 JUL 2022\n10:00 AM IST',
#  '1 JUL 2022\n3:30 PM IST',
#  '4 JUL 2022\n10:00 AM IST',
#  '23 JUN 2022\n2:30 PM IST',
#  '25 JUN 2022\n2:30 PM IST',
#  '26 JUN 2022\n9:00 PM IST',
#  '27 JUN 2022\n2:30 PM IST',
#  '28 JUN 2022\n9:00 PM IST',
#  '1 JUL 2022\n10:00 AM IST',
#  '1 JUL 2022\n3:30 PM IST',
#  '4 JUL 2022\n10:00 AM IST',
#  '23 JUN 2022\n2:30 PM IST',
#  '25 JUN 2022\n2:30 PM IST',
#  '26 JUN 2022\n9:00 PM IST',
#  '27 JUN 2022\n2:30 PM IST',
#  '28 JUN 2022\n9:00 PM IST',
#  '1 JUL 2022\n10:00 AM IST',
#  '1 JUL 2022\n3:30 PM IST',
#  '4 JUL 2022\n10:00 AM IST',
#  '23 JUN 2022\n2:30 PM IST',
#  '25 JUN 2022\n2:30 PM IST',
#  '26 JUN 2022\n9:00 PM IST',
#  '27 JUN 2022\n2:30 PM IST',
#  '28 JUN 2022\n9:00 PM IST',
#  '1 JUL 2022\n10:00 AM IST',
#  '1 JUL 2022\n3:30 PM IST',
#  '4 JUL 2022\n10:00 AM IST',
#  '23 JUN 2022\n2:30 PM IST',
#  '25 JUN 2022\n2:30 PM IST',
#  '26 JUN 2022\n9:00 PM IST',
#  '27 JUN 2022\n2:30 PM IST',
#  '28 JUN 2022\n9:00 PM IST',
#  '1 JUL 2022\n10:00 AM IST',
#  '1 JUL 2022\n3:30 PM IST',
#  '4 JUL 2022\n10:00 AM IST',
#  '23 JUN 2022\n2:30 PM IST',
#  '25 JUN 2022\n2:30 PM IST',
#  '26 JUN 2022\n9:00 PM IST',
#  '27 JUN 2022\n2:30 PM IST',
#  '28 JUN 2022\n9:00 PM IST',
#  '1 JUL 2022\n10:00 AM IST',
#  '1 JUL 2022\n3:30 PM IST',
#  '4 JUL 2022\n10:00 AM IST',
#  '23 JUN 2022\n2:30 PM IST',
#  '25 JUN 2022\n2:30 PM IST',
#  '26 JUN 2022\n9:00 PM IST',
#  '27 JUN 2022\n2:30 PM IST',
#  '28 JUN 2022\n9:00 PM IST',
#  '1 JUL 2022\n10:00 AM IST',
#  '1 JUL 2022\n3:30 PM IST',
#  '4 JUL 2022\n10:00 AM IST',
#  '23 JUN 2022\n2:30 PM IST',
#  '25 JUN 2022\n2:30 PM IST',
#  '26 JUN 2022\n9:00 PM IST',
#  '27 JUN 2022\n2:30 PM IST',
#  '28 JUN 2022\n9:00 PM IST',
#  '1 JUL 2022\n10:00 AM IST',
#  '1 JUL 2022\n3:30 PM IST',
#  '4 JUL 2022\n10:00 AM IST',
#  '23 JUN 2022\n2:30 PM IST',
#  '25 JUN 2022\n2:30 PM IST',
#  '26 JUN 2022\n9:00 PM IST',
#  '27 JUN 2022\n2:30 PM IST',
#  '28 JUN 2022\n9:00 PM IST',
#  '1 JUL 2022\n10:00 AM IST',
#  '1 JUL 2022\n3:30 PM IST',
#  '4 JUL 2022\n10:00 AM IST',
#  '23 JUN 2022\n2:30 PM IST',
#  '25 JUN 2022\n2:30 PM IST',
#  '26 JUN 2022\n9:00 PM IST',
#  '27 JUN 2022\n2:30 PM IST',
#  '28 JUN 2022\n9:00 PM IST',
#  '1 JUL 2022\n10:00 AM IST',
#  '1 JUL 2022\n3:30 PM IST',
#  '4 JUL 2022\n10:00 AM IST']

# %%
#Creating dataframe
df=pd.DataFrame({})

df['matchtitle_tags']=matchtitle_tags[:41]
df['date_tags']=date_tags[:41]
df['series_tags']=series_tags[:41]
df['place_tags']=place_tags[:41]

# %%
df
# Out:
#                                   matchtitle_tags                 date_tags  \
# 0   INDIA WOMEN TOUR OF SRI LANKA T20 SERIES 2022  23 JUN 2022\n2:30 PM IST
# 1   INDIA WOMEN TOUR OF SRI LANKA T20 SERIES 2022  25 JUN 2022\n2:30 PM IST
# 2           INDIA TOUR OF IRELAND T20 SERIES 2022  26 JUN 2022\n9:00 PM IST
# 3   INDIA WOMEN TOUR OF SRI LANKA T20 SERIES 2022  27 JUN 2022\n2:30 PM IST
# 4           INDIA TOUR OF IRELAND T20 SERIES 2022  28 JUN 2022\n9:00 PM IST
# 5   INDIA WOMEN TOUR OF SRI LANKA ODI SERIES 2022  1 JUL 2022\n10:00 AM IST
# 6          INDIA TOUR OF ENGLAND TEST SERIES 2021   1 JUL 2022\n3:30 PM IST
# 7   INDIA WOMEN TOUR OF SRI LANKA ODI SERIES 2022  4 JUL 2022\n10:00 AM IST
# 8   INDIA WOMEN TOUR OF SRI LANKA T20 SERIES 2022  23 JUN 2022\n2:30 PM IST
# 9   INDIA WOMEN TOUR OF SRI LANKA T20 SERIES 2022  25 JUN 2022\n2:30 PM IST
# 10          INDIA TOUR OF IRELAND T20 SERIES 2022  26 JUN 2022\n9:00 PM IST
# 11  INDIA WOMEN TOUR OF SRI LANKA T20 SERIES 2022  27 JUN 2022\n2:30 PM IST
# 12          INDIA TOUR OF IRELAND T20 SERIES 2022  28 JUN 2022\n9:00 PM IST
# 13  INDIA WOMEN TOUR OF SRI LANKA ODI SERIES 2022  1 JUL 2022\n10:00 AM IST
# 14         INDIA TOUR OF ENGLAND TEST SERIES 2021   1 JUL 2022\n3:30 PM IST
# 15  INDIA WOMEN TOUR OF SRI LANKA ODI SERIES 2022  4 JUL 2022\n10:00 AM IST
# 16  INDIA WOMEN TOUR OF SRI LANKA T20 SERIES 2022  23 JUN 2022\n2:30 PM IST
# 17  INDIA WOMEN TOUR OF SRI LANKA T20 SERIES 2022  25 JUN 2022\n2:30 PM IST
# 18          INDIA TOUR OF IRELAND T20 SERIES 2022  26 JUN 2022\n9:00 PM IST
# 19  INDIA WOMEN TOUR OF SRI LANKA T20 SERIES 2022  27 JUN 2022\n2:30 PM IST
# 20          INDIA TOUR OF IRELAND T20 SERIES 2022  28 JUN 2022\n9:00 PM IST
# 21  INDIA WOMEN TOUR OF SRI LANKA ODI SERIES 2022  1 JUL 2022\n10:00 AM IST
# 22         INDIA TOUR OF ENGLAND TEST SERIES 2021   1 JUL 2022\n3:30 PM IST
# 23  INDIA WOMEN TOUR OF SRI LANKA ODI SERIES 2022  4 JUL 2022\n10:00 AM IST
# 24  INDIA WOMEN TOUR OF SRI LANKA T20 SERIES 2022  23 JUN 2022\n2:30 PM IST
# 25  INDIA WOMEN TOUR OF SRI LANKA T20 SERIES 2022  25 JUN 2022\n2:30 PM IST
# 26          INDIA TOUR OF IRELAND T20 SERIES 2022  26 JUN 2022\n9:00 PM IST
# 27  INDIA WOMEN TOUR OF SRI LANKA T20 SERIES 2022  27 JUN 2022\n2:30 PM IST
# 28          INDIA TOUR OF IRELAND T20 SERIES 2022  28 JUN 2022\n9:00 PM IST
# 29  INDIA WOMEN TOUR OF SRI LANKA ODI SERIES 2022  1 JUL 2022\n10:00 AM IST
# 30         INDIA TOUR OF ENGLAND TEST SERIES 2021   1 JUL 2022\n3:30 PM IST
# 31  INDIA WOMEN TOUR OF SRI LANKA ODI SERIES 2022  4 JUL 2022\n10:00 AM IST
# 32  INDIA WOMEN TOUR OF SRI LANKA T20 SERIES 2022  23 JUN 2022\n2:30 PM IST
# 33  INDIA WOMEN TOUR OF SRI LANKA T20 SERIES 2022  25 JUN 2022\n2:30 PM IST
# 34          INDIA TOUR OF IRELAND T20 SERIES 2022  26 JUN 2022\n9:00 PM IST
# 35  INDIA WOMEN TOUR OF SRI LANKA T20 SERIES 2022  27 JUN 2022\n2:30 PM IST
# 36          INDIA TOUR OF IRELAND T20 SERIES 2022  28 JUN 2022\n9:00 PM IST
# 37  INDIA WOMEN TOUR OF SRI LANKA ODI SERIES 2022  1 JUL 2022\n10:00 AM IST
# 38         INDIA TOUR OF ENGLAND TEST SERIES 2021   1 JUL 2022\n3:30 PM IST
# 39  INDIA WOMEN TOUR OF SRI LANKA ODI SERIES 2022  4 JUL 2022\n10:00 AM IST
# 40  INDIA WOMEN TOUR OF SRI LANKA T20 SERIES 2022  23 JUN 2022\n2:30 PM IST
#
#                          series_tags                                place_tags
# 0   Sri Lanka Women\nvs\nIndia Women   Rangiri Dambulla International Stadium,
# 1   Sri Lanka Women\nvs\nIndia Women   Rangiri Dambulla International Stadium,
# 2                 Ireland\nvs\nIndia                              The Village,
# 3   Sri Lanka Women\nvs\nIndia Women   Rangiri Dambulla International Stadium,
# 4                 Ireland\nvs\nIndia                              The Village,
# 5   Sri Lanka Women\nvs\nIndia Women  Pallekele International Cricket Stadium,
# 6                 England\nvs\nIndia                                Edgbaston,
# 7   Sri Lanka Women\nvs\nIndia Women  Pallekele International Cricket Stadium,
# 8   Sri Lanka Women\nvs\nIndia Women   Rangiri Dambulla International Stadium,
# 9   Sri Lanka Women\nvs\nIndia Women   Rangiri Dambulla International Stadium,
# 10                Ireland\nvs\nIndia                              The Village,
# 11  Sri Lanka Women\nvs\nIndia Women   Rangiri Dambulla International Stadium,
# 12                Ireland\nvs\nIndia                              The Village,
# 13  Sri Lanka Women\nvs\nIndia Women  Pallekele International Cricket Stadium,
# 14                England\nvs\nIndia                                Edgbaston,
# 15  Sri Lanka Women\nvs\nIndia Women  Pallekele International Cricket Stadium,
# 16  Sri Lanka Women\nvs\nIndia Women   Rangiri Dambulla International Stadium,
# 17  Sri Lanka Women\nvs\nIndia Women   Rangiri Dambulla International Stadium,
# 18                Ireland\nvs\nIndia                              The Village,
# 19  Sri Lanka Women\nvs\nIndia Women   Rangiri Dambulla International Stadium,
# 20                Ireland\nvs\nIndia                              The Village,
# 21  Sri Lanka Women\nvs\nIndia Women  Pallekele International Cricket Stadium,
# 22                England\nvs\nIndia                                Edgbaston,
# 23  Sri Lanka Women\nvs\nIndia Women  Pallekele International Cricket Stadium,
# 24  Sri Lanka Women\nvs\nIndia Women   Rangiri Dambulla International Stadium,
# 25  Sri Lanka Women\nvs\nIndia Women   Rangiri Dambulla International Stadium,
# 26                Ireland\nvs\nIndia                              The Village,
# 27  Sri Lanka Women\nvs\nIndia Women   Rangiri Dambulla International Stadium,
# 28                Ireland\nvs\nIndia                              The Village,
# 29  Sri Lanka Women\nvs\nIndia Women  Pallekele International Cricket Stadium,
# 30                England\nvs\nIndia                                Edgbaston,
# 31  Sri Lanka Women\nvs\nIndia Women  Pallekele International Cricket Stadium,
# 32  Sri Lanka Women\nvs\nIndia Women   Rangiri Dambulla International Stadium,
# 33  Sri Lanka Women\nvs\nIndia Women   Rangiri Dambulla International Stadium,
# 34                Ireland\nvs\nIndia                              The Village,
# 35  Sri Lanka Women\nvs\nIndia Women   Rangiri Dambulla International Stadium,
# 36                Ireland\nvs\nIndia                              The Village,
# 37  Sri Lanka Women\nvs\nIndia Women  Pallekele International Cricket Stadium,
# 38                England\nvs\nIndia                                Edgbaston,
# 39  Sri Lanka Women\nvs\nIndia Women  Pallekele International Cricket Stadium,
# 40  Sri Lanka Women\nvs\nIndia Women   Rangiri Dambulla International Stadium,

# %%
# !pip install selenium
# !pip install requests
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: selenium in c:\users\shailja tiwari\appdata\roaming\python\python39\site-packages (4.2.0)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\shailja tiwari\appdata\roaming\python\python39\site-packages (from selenium) (0.9.2)
# Requirement already satisfied: urllib3[secure,socks]~=1.26 in c:\programdata\anaconda3\lib\site-packages (from selenium) (1.26.9)
# Requirement already satisfied: trio~=0.17 in c:\users\shailja tiwari\appdata\roaming\python\python39\site-packages (from selenium) (0.21.0)
# Requirement already satisfied: sortedcontainers in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: outcome in c:\users\shailja tiwari\appdata\roaming\python\python39\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: sniffio in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: cffi>=1.14 in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.0)
# Requirement already satisfied: attrs>=19.2.0 in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium) (21.4.0)
# Requirement already satisfied: idna in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.3)
# Requirement already satisfied: async-generator>=1.9 in c:\users\shailja tiwari\appdata\roaming\python\python39\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: pycparser in c:\programdata\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: wsproto>=0.14 in c:\users\shailja tiwari\appdata\roaming\python\python39\site-packages (from trio-websocket~=0.9->selenium) (1.1.0)
# Requirement already satisfied: cryptography>=1.3.4 in c:\programdata\anaconda3\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium) (3.4.8)
# Requirement already satisfied: certifi in c:\programdata\anaconda3\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium) (2021.10.8)
# Requirement already satisfied: pyOpenSSL>=0.14 in c:\programdata\anaconda3\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium) (21.0.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\programdata\anaconda3\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: six>=1.5.2 in c:\programdata\anaconda3\lib\site-packages (from pyOpenSSL>=0.14->urllib3[secure,socks]~=1.26->selenium) (1.16.0)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\shailja tiwari\appdata\roaming\python\python39\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.13.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (2.27.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests) (3.3)

# %% [markdown]
# # Answer 6

# %%
# Importing all necessary imports for Beutiful Soup and Selenium library
import pandas as pd
import time
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException, ElementNotInteractableException
import requests
from selenium.common.exceptions import TimeoutException


import selenium 


import warnings
warnings.filterwarnings('ignore')

# %%
#IMPORTING chrome driver exe


driver = webdriver.Chrome('chromedriver.exe')

# %%
driver.get('https:/www.billboard.com/')

# %%
song = []
artist = []
last_week_rank = []
peak_rank = []
weeks_on_board = []

# %%
song=[]
for i in range(10):
    for j in driver.find_elements_by_xpath("//h3[@class='c-title  a-no-trucate a-font-primary-bold-s u-letter-spacing-0021 u-font-size-23@tablet lrv-u-font-size-16 u-line-height-125 u-line-height-normal@mobile-max a-truncate-ellipsis u-max-width-245 u-max-width-230@tablet-only u-letter-spacing-0028@tablet']"):
        date_tags.append(j.text)
    time.sleep(5)
song
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# Input In [22], in <cell line: 2>()
#       1 song=[]
#       2 for i in range(10):
# ----> 3     for j in driver.find_elements_by_xpath("//h3[@class='c-title  a-no-trucate a-font-primary-bold-s u-letter-spacing-0021 u-font-size-23@tablet lrv-u-font-size-16 u-line-height-125 u-line-height-normal@mobile-max a-truncate-ellipsis u-max-width-245 u-max-width-230@tablet-only u-letter-spacing-0028@tablet']"):
#       4         date_tags.append(j.text)
#       5     time.sleep(5)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\selenium\webdriver\remote\webdriver.py:549, in WebDriver.find_elements_by_xpath(self, xpath)
#     529 """
#     530 Finds multiple elements by xpath.
#     531
#    (...)
#     542         elements = driver.find_elements_by_xpath("//div[contains(@class, 'foo')]")
#     543 """
#     544 warnings.warn(
#     545     "find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead",
#     546     DeprecationWarning,
#     547     stacklevel=2,
#     548 )
# --> 549 return self.find_elements(by=By.XPATH, value=xpath)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\selenium\webdriver\remote\webdriver.py:1284, in WebDriver.find_elements(self, by, value)
#    1280     value = '[name="%s"]' % value
#    1282 # Return empty list if driver returns null
#    1283 # See https://github.com/SeleniumHQ/selenium/issues/4555
# -> 1284 return self.execute(Command.FIND_ELEMENTS, {
#    1285     'using': by,
#    1286     'value': value})['value'] or []
#
# File ~\AppData\Roaming\Python\Python39\site-packages\selenium\webdriver\remote\webdriver.py:430, in WebDriver.execute(self, driver_command, params)
#     428 response = self.command_executor.execute(driver_command, params)
#     429 if response:
# --> 430     self.error_handler.check_response(response)
#     431     response['value'] = self._unwrap_value(
#     432         response.get('value', None))
#     433     return response
#
# File ~\AppData\Roaming\Python\Python39\site-packages\selenium\webdriver\remote\errorhandler.py:247, in ErrorHandler.check_response(self, response)
#     245         alert_text = value['alert'].get('text')
#     246     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247 raise exception_class(message, screen, stacktrace)
#
# WebDriverException: Message: unknown error: unexpected command response
#   (Session info: chrome=103.0.5060.53)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x0045D953+2414931]
# 	Ordinal0 [0x003EF5E1+1963489]
# 	Ordinal0 [0x002DC6B8+837304]
# 	Ordinal0 [0x002CEB34+781108]
# 	Ordinal0 [0x002CE06A+778346]
# 	Ordinal0 [0x002CD646+775750]
# 	Ordinal0 [0x002CCEBC+773820]
# 	Ordinal0 [0x002CCD59+773465]
# 	Ordinal0 [0x002DDA70+842352]
# 	Ordinal0 [0x003340DB+1196251]
# 	Ordinal0 [0x003242B6+1131190]
# 	Ordinal0 [0x002FE860+976992]
# 	Ordinal0 [0x002FF756+980822]
# 	GetHandleVerifier [0x006CCC62+2510274]
# 	GetHandleVerifier [0x006BF760+2455744]
# 	GetHandleVerifier [0x004EEABA+551962]
# 	GetHandleVerifier [0x004ED916+547446]
# 	Ordinal0 [0x003F5F3B+1990459]
# 	Ordinal0 [0x003FA898+2009240]
# 	Ordinal0 [0x003FA985+2009477]
# 	Ordinal0 [0x00403AD1+2046673]
# 	BaseThreadInitThunk [0x75BC6739+25]
# 	RtlGetFullPathName_UEx [0x77E78FEF+1215]
# 	RtlGetFullPathName_UEx [0x77E78FBD+1165]

# %% [markdown]
# # Answer 7

# %%
import time
# Let's activate and load the chrome browser
driver=webdriver.Chrome('chromedriver.exe')
driver.maximize_window()

# Let's open the URL
driver.get('https://www.naukri.com/')
driver.implicitly_wait(3)

# Let's navigate and clciking on the recruiter option on the search pane
recruiter=driver.find_element_by_xpath("//ul[@class='midSec menu']/li[2]/a")
driver.get(recruiter.get_attribute('href'))
time.sleep(5)
# Let's navigate to the search bar and Type Data Science in the search bar and click search
search_field_designation=driver.find_element_by_xpath("//input[@class='sugInp']")
search_field_designation.send_keys("Data Science")
driver.find_element_by_xpath("//button[@class='fl qsbSrch blueBtn']").click()
time.sleep(5)
# Let's create an empty lists to store the scraping data
Name=[]
Designation=[] 
Company=[] 
Skills_they_hire_for=[] 
Location=[]

# Scrape the data as metioned in question
try:
    name = driver.find_elements_by_xpath('//span[@class="fl ellipsis"]')
except NoSuchElementException:
    print("Name element N/a")

for i in name:
    try:
        Name.append(i.text)
    except:
        Name.append('--')
try:
    designation = driver.find_elements_by_xpath('//span[@class="ellipsis clr"]')
except NoSuchElementException:
    print("Designation element N/a")

for i in designation:
    try:
        Designation.append(i.text)
    except:
        Designation.append('--')
try:
    company = driver.find_elements_by_xpath('//p[@class="highlightable"]/a[2]')
except NoSuchElementException:
    print("Company element N/a")

for i in company:
    try:
        Company.append(i.text)
    except:
        Company.append('--')
try:
    skill = driver.find_elements_by_xpath('//div[@class="hireSec highlightable"]')
except NoSuchElementException:
    print("Skill element N/a")

for i in skill:
    try:
        Skills_they_hire_for.append(i.text)
    except:
        Skills_they_hire_for.append('--')
try:
    loc = driver.find_elements_by_xpath('//p[@class="highlightable"]/span[2]')
except NoSuchElementException:
    print("Location element N/a")

for i in loc:
    try:
        Location.append(i.text)
    except NoSuchElementException:        
        Location.append("---")
# Let's check the length of the scrape data
print(len(Name),len(Designation),len(Company),len(Skills_they_hire_for),len(Location))


# Let's create the dataframe from the scraped data
Data_Science=pd.DataFrame({})
Data_Science['Name']=Name[0:45]
Data_Science['Designation']=Designation[0:45]
Data_Science['Company']=Company[0:45]
Data_Science['Skills they Hire for']= Skills_they_hire_for[0:45]
Data_Science['Location']=Location[0:45]
Data_Science
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Input In [23], in <cell line: 11>()
#       8 driver.implicitly_wait(3)
#      10 # Let's navigate and clciking on the recruiter option on the search pane
# ---> 11 recruiter=driver.find_element_by_xpath("//ul[@class='midSec menu']/li[2]/a")
#      12 driver.get(recruiter.get_attribute('href'))
#      13 time.sleep(5)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\selenium\webdriver\remote\webdriver.py:526, in WebDriver.find_element_by_xpath(self, xpath)
#     504 """
#     505 Finds an element by xpath.
#     506
#    (...)
#     519         element = driver.find_element_by_xpath('//div/td[1]')
#     520 """
#     521 warnings.warn(
#     522     "find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead",
#     523     DeprecationWarning,
#     524     stacklevel=2,
#     525 )
# --> 526 return self.find_element(by=By.XPATH, value=xpath)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\selenium\webdriver\remote\webdriver.py:1251, in WebDriver.find_element(self, by, value)
#    1248     by = By.CSS_SELECTOR
#    1249     value = '[name="%s"]' % value
# -> 1251 return self.execute(Command.FIND_ELEMENT, {
#    1252     'using': by,
#    1253     'value': value})['value']
#
# File ~\AppData\Roaming\Python\Python39\site-packages\selenium\webdriver\remote\webdriver.py:430, in WebDriver.execute(self, driver_command, params)
#     428 response = self.command_executor.execute(driver_command, params)
#     429 if response:
# --> 430     self.error_handler.check_response(response)
#     431     response['value'] = self._unwrap_value(
#     432         response.get('value', None))
#     433     return response
#
# File ~\AppData\Roaming\Python\Python39\site-packages\selenium\webdriver\remote\errorhandler.py:247, in ErrorHandler.check_response(self, response)
#     245         alert_text = value['alert'].get('text')
#     246     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//ul[@class='midSec menu']/li[2]/a"}
#   (Session info: chrome=103.0.5060.53)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x0045D953+2414931]
# 	Ordinal0 [0x003EF5E1+1963489]
# 	Ordinal0 [0x002DC6B8+837304]
# 	Ordinal0 [0x00309500+1021184]
# 	Ordinal0 [0x0030979B+1021851]
# 	Ordinal0 [0x00336502+1205506]
# 	Ordinal0 [0x003244E4+1131748]
# 	Ordinal0 [0x00334812+1198098]
# 	Ordinal0 [0x003242B6+1131190]
# 	Ordinal0 [0x002FE860+976992]
# 	Ordinal0 [0x002FF756+980822]
# 	GetHandleVerifier [0x006CCC62+2510274]
# 	GetHandleVerifier [0x006BF760+2455744]
# 	GetHandleVerifier [0x004EEABA+551962]
# 	GetHandleVerifier [0x004ED916+547446]
# 	Ordinal0 [0x003F5F3B+1990459]
# 	Ordinal0 [0x003FA898+2009240]
# 	Ordinal0 [0x003FA985+2009477]
# 	Ordinal0 [0x00403AD1+2046673]
# 	BaseThreadInitThunk [0x75BC6739+25]
# 	RtlGetFullPathName_UEx [0x77E78FEF+1215]
# 	RtlGetFullPathName_UEx [0x77E78FBD+1165]

# %% [markdown]
# # Answer 5

# %%
driver.get("https://github.com/")
time.sleep(6)

# %%
repositorytitle_tags=[]
for i in range(10):
    for j in driver.find_elements_by_xpath("//a"):
        repositorytitle_tags.append(j.text)
    time.sleep(5)

# %%
repositorytitle_tags
# Out:
# ['Skip to content',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Team',
#  'Enterprise',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Marketplace',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Sign in',
#  'Sign up',
#  '',
#  '',
#  '',
#  'Code',
#  'Collaborate',
#  'Develop',
#  'Automate',
#  'Secure',
#  'Community',
#  '',
#  'Sign up for GitHub',
#  '',
#  '',
#  'Create a new organization for free',
#  'GitHub Mobile',
#  '',
#  '',
#  'GitHub Desktop',
#  'GitHub CLI',
#  'Learn more about GitHub Codespaces',
#  'Learn more about GitHub Copilot',
#  'Learn more about GitHub Actions',
#  '',
#  'Learn more about Dependabot',
#  'Learn more about advanced security',
#  'Learn how to get started with Discussions',
#  '',
#  'Sign up for GitHub',
#  'Contact Sales',
#  'tensorflow/tensorflow\nAn Open Source Machine Learning Framework for Everyone',
#  'Build blazing fast, modern apps and websites with React',
#  '',
#  'rust-lang/rust\nEmpowering everyone to build reliable and efficient software.',
#  'flutter/flutter\nFlutter makes it easy and fast to build beautiful apps for mobile and beyond.',
#  '',
#  'apple/swift\nThe Swift Programming Language',
#  'ansible/ansible\nAnsible is a radically simple IT automation platform.',
#  '',
#  'ohmyzsh/ohmyzsh\n🙃 A delightful community-driven framework for managing your zsh configuration.',
#  'facebook/react\nA declarative, efficient, and flexible JavaScript library for building user interfaces.',
#  'npm/cli\nThe package manager for JavaScript',
#  '',
#  'Features',
#  'Security',
#  'Team',
#  'Enterprise',
#  'Customer stories',
#  'The ReadME Project',
#  'Pricing',
#  'Resources',
#  'Roadmap',
#  'Developer API',
#  'Partners',
#  'Atom',
#  'Electron',
#  'GitHub Desktop',
#  'Docs',
#  'Community Forum',
#  'Professional Services',
#  'Skills',
#  'Status',
#  'Contact GitHub',
#  'About',
#  'Blog',
#  'Careers',
#  'Press',
#  'Inclusion',
#  'Social Impact',
#  'Shop',
#  'GitHub on Twitter',
#  'GitHub on Facebook',
#  'GitHub on YouTube',
#  'GitHub on LinkedIn',
#  'GitHub’s organization on GitHub',
#  'Terms',
#  'Privacy',
#  'Site Map',
#  'What is Git?',
#  '',
#  '',
#  'Skip to content',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Team',
#  'Enterprise',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Marketplace',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Sign in',
#  'Sign up',
#  '',
#  '',
#  '',
#  'Code',
#  'Collaborate',
#  'Develop',
#  'Automate',
#  'Secure',
#  'Community',
#  '',
#  'Sign up for GitHub',
#  '',
#  '',
#  'Create a new organization for free',
#  'GitHub Mobile',
#  '',
#  '',
#  'GitHub Desktop',
#  'GitHub CLI',
#  'Learn more about GitHub Codespaces',
#  'Learn more about GitHub Copilot',
#  'Learn more about GitHub Actions',
#  '',
#  'Learn more about Dependabot',
#  'Learn more about advanced security',
#  'Learn how to get started with Discussions',
#  '',
#  'Sign up for GitHub',
#  'Contact Sales',
#  'tensorflow/tensorflow\nAn Open Source Machine Learning Framework for Everyone',
#  'Build blazing fast, modern apps and websites with React',
#  '',
#  'rust-lang/rust\nEmpowering everyone to build reliable and efficient software.',
#  'flutter/flutter\nFlutter makes it easy and fast to build beautiful apps for mobile and beyond.',
#  '',
#  'apple/swift\nThe Swift Programming Language',
#  'ansible/ansible\nAnsible is a radically simple IT automation platform.',
#  '',
#  'ohmyzsh/ohmyzsh\n🙃 A delightful community-driven framework for managing your zsh configuration.',
#  'facebook/react\nA declarative, efficient, and flexible JavaScript library for building user interfaces.',
#  'npm/cli\nThe package manager for JavaScript',
#  '',
#  'Features',
#  'Security',
#  'Team',
#  'Enterprise',
#  'Customer stories',
#  'The ReadME Project',
#  'Pricing',
#  'Resources',
#  'Roadmap',
#  'Developer API',
#  'Partners',
#  'Atom',
#  'Electron',
#  'GitHub Desktop',
#  'Docs',
#  'Community Forum',
#  'Professional Services',
#  'Skills',
#  'Status',
#  'Contact GitHub',
#  'About',
#  'Blog',
#  'Careers',
#  'Press',
#  'Inclusion',
#  'Social Impact',
#  'Shop',
#  'GitHub on Twitter',
#  'GitHub on Facebook',
#  'GitHub on YouTube',
#  'GitHub on LinkedIn',
#  'GitHub’s organization on GitHub',
#  'Terms',
#  'Privacy',
#  'Site Map',
#  'What is Git?',
#  '',
#  '',
#  'Skip to content',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Team',
#  'Enterprise',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Marketplace',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Sign in',
#  'Sign up',
#  '',
#  '',
#  '',
#  'Code',
#  'Collaborate',
#  'Develop',
#  'Automate',
#  'Secure',
#  'Community',
#  '',
#  'Sign up for GitHub',
#  '',
#  '',
#  'Create a new organization for free',
#  'GitHub Mobile',
#  '',
#  '',
#  'GitHub Desktop',
#  'GitHub CLI',
#  'Learn more about GitHub Codespaces',
#  'Learn more about GitHub Copilot',
#  'Learn more about GitHub Actions',
#  '',
#  'Learn more about Dependabot',
#  'Learn more about advanced security',
#  'Learn how to get started with Discussions',
#  '',
#  'Sign up for GitHub',
#  'Contact Sales',
#  'tensorflow/tensorflow\nAn Open Source Machine Learning Framework for Everyone',
#  'Build blazing fast, modern apps and websites with React',
#  '',
#  'rust-lang/rust\nEmpowering everyone to build reliable and efficient software.',
#  'flutter/flutter\nFlutter makes it easy and fast to build beautiful apps for mobile and beyond.',
#  '',
#  'apple/swift\nThe Swift Programming Language',
#  'ansible/ansible\nAnsible is a radically simple IT automation platform.',
#  '',
#  'ohmyzsh/ohmyzsh\n🙃 A delightful community-driven framework for managing your zsh configuration.',
#  'facebook/react\nA declarative, efficient, and flexible JavaScript library for building user interfaces.',
#  'npm/cli\nThe package manager for JavaScript',
#  '',
#  'Features',
#  'Security',
#  'Team',
#  'Enterprise',
#  'Customer stories',
#  'The ReadME Project',
#  'Pricing',
#  'Resources',
#  'Roadmap',
#  'Developer API',
#  'Partners',
#  'Atom',
#  'Electron',
#  'GitHub Desktop',
#  'Docs',
#  'Community Forum',
#  'Professional Services',
#  'Skills',
#  'Status',
#  'Contact GitHub',
#  'About',
#  'Blog',
#  'Careers',
#  'Press',
#  'Inclusion',
#  'Social Impact',
#  'Shop',
#  'GitHub on Twitter',
#  'GitHub on Facebook',
#  'GitHub on YouTube',
#  'GitHub on LinkedIn',
#  'GitHub’s organization on GitHub',
#  'Terms',
#  'Privacy',
#  'Site Map',
#  'What is Git?',
#  '',
#  '',
#  'Skip to content',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Team',
#  'Enterprise',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Marketplace',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Sign in',
#  'Sign up',
#  '',
#  '',
#  '',
#  'Code',
#  'Collaborate',
#  'Develop',
#  'Automate',
#  'Secure',
#  'Community',
#  '',
#  'Sign up for GitHub',
#  '',
#  '',
#  'Create a new organization for free',
#  'GitHub Mobile',
#  '',
#  '',
#  'GitHub Desktop',
#  'GitHub CLI',
#  'Learn more about GitHub Codespaces',
#  'Learn more about GitHub Copilot',
#  'Learn more about GitHub Actions',
#  '',
#  'Learn more about Dependabot',
#  'Learn more about advanced security',
#  'Learn how to get started with Discussions',
#  '',
#  'Sign up for GitHub',
#  'Contact Sales',
#  'tensorflow/tensorflow\nAn Open Source Machine Learning Framework for Everyone',
#  'Build blazing fast, modern apps and websites with React',
#  '',
#  'rust-lang/rust\nEmpowering everyone to build reliable and efficient software.',
#  'flutter/flutter\nFlutter makes it easy and fast to build beautiful apps for mobile and beyond.',
#  '',
#  'apple/swift\nThe Swift Programming Language',
#  'ansible/ansible\nAnsible is a radically simple IT automation platform.',
#  '',
#  'ohmyzsh/ohmyzsh\n🙃 A delightful community-driven framework for managing your zsh configuration.',
#  'facebook/react\nA declarative, efficient, and flexible JavaScript library for building user interfaces.',
#  'npm/cli\nThe package manager for JavaScript',
#  '',
#  'Features',
#  'Security',
#  'Team',
#  'Enterprise',
#  'Customer stories',
#  'The ReadME Project',
#  'Pricing',
#  'Resources',
#  'Roadmap',
#  'Developer API',
#  'Partners',
#  'Atom',
#  'Electron',
#  'GitHub Desktop',
#  'Docs',
#  'Community Forum',
#  'Professional Services',
#  'Skills',
#  'Status',
#  'Contact GitHub',
#  'About',
#  'Blog',
#  'Careers',
#  'Press',
#  'Inclusion',
#  'Social Impact',
#  'Shop',
#  'GitHub on Twitter',
#  'GitHub on Facebook',
#  'GitHub on YouTube',
#  'GitHub on LinkedIn',
#  'GitHub’s organization on GitHub',
#  'Terms',
#  'Privacy',
#  'Site Map',
#  'What is Git?',
#  '',
#  '',
#  'Skip to content',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Team',
#  'Enterprise',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Marketplace',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Sign in',
#  'Sign up',
#  '',
#  '',
#  '',
#  'Code',
#  'Collaborate',
#  'Develop',
#  'Automate',
#  'Secure',
#  'Community',
#  '',
#  'Sign up for GitHub',
#  '',
#  '',
#  'Create a new organization for free',
#  'GitHub Mobile',
#  '',
#  '',
#  'GitHub Desktop',
#  'GitHub CLI',
#  'Learn more about GitHub Codespaces',
#  'Learn more about GitHub Copilot',
#  'Learn more about GitHub Actions',
#  '',
#  'Learn more about Dependabot',
#  'Learn more about advanced security',
#  'Learn how to get started with Discussions',
#  '',
#  'Sign up for GitHub',
#  'Contact Sales',
#  'tensorflow/tensorflow\nAn Open Source Machine Learning Framework for Everyone',
#  'Build blazing fast, modern apps and websites with React',
#  '',
#  'rust-lang/rust\nEmpowering everyone to build reliable and efficient software.',
#  'flutter/flutter\nFlutter makes it easy and fast to build beautiful apps for mobile and beyond.',
#  '',
#  'apple/swift\nThe Swift Programming Language',
#  'ansible/ansible\nAnsible is a radically simple IT automation platform.',
#  '',
#  'ohmyzsh/ohmyzsh\n🙃 A delightful community-driven framework for managing your zsh configuration.',
#  'facebook/react\nA declarative, efficient, and flexible JavaScript library for building user interfaces.',
#  'npm/cli\nThe package manager for JavaScript',
#  '',
#  'Features',
#  'Security',
#  'Team',
#  'Enterprise',
#  'Customer stories',
#  'The ReadME Project',
#  'Pricing',
#  'Resources',
#  'Roadmap',
#  'Developer API',
#  'Partners',
#  'Atom',
#  'Electron',
#  'GitHub Desktop',
#  'Docs',
#  'Community Forum',
#  'Professional Services',
#  'Skills',
#  'Status',
#  'Contact GitHub',
#  'About',
#  'Blog',
#  'Careers',
#  'Press',
#  'Inclusion',
#  'Social Impact',
#  'Shop',
#  'GitHub on Twitter',
#  'GitHub on Facebook',
#  'GitHub on YouTube',
#  'GitHub on LinkedIn',
#  'GitHub’s organization on GitHub',
#  'Terms',
#  'Privacy',
#  'Site Map',
#  'What is Git?',
#  '',
#  '',
#  'Skip to content',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Team',
#  'Enterprise',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Marketplace',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Sign in',
#  'Sign up',
#  '',
#  '',
#  '',
#  'Code',
#  'Collaborate',
#  'Develop',
#  'Automate',
#  'Secure',
#  'Community',
#  '',
#  'Sign up for GitHub',
#  '',
#  '',
#  'Create a new organization for free',
#  'GitHub Mobile',
#  '',
#  '',
#  'GitHub Desktop',
#  'GitHub CLI',
#  'Learn more about GitHub Codespaces',
#  'Learn more about GitHub Copilot',
#  'Learn more about GitHub Actions',
#  '',
#  'Learn more about Dependabot',
#  'Learn more about advanced security',
#  'Learn how to get started with Discussions',
#  '',
#  'Sign up for GitHub',
#  'Contact Sales',
#  'tensorflow/tensorflow\nAn Open Source Machine Learning Framework for Everyone',
#  'Build blazing fast, modern apps and websites with React',
#  '',
#  'rust-lang/rust\nEmpowering everyone to build reliable and efficient software.',
#  'flutter/flutter\nFlutter makes it easy and fast to build beautiful apps for mobile and beyond.',
#  '',
#  'apple/swift\nThe Swift Programming Language',
#  'ansible/ansible\nAnsible is a radically simple IT automation platform.',
#  '',
#  'ohmyzsh/ohmyzsh\n🙃 A delightful community-driven framework for managing your zsh configuration.',
#  'facebook/react\nA declarative, efficient, and flexible JavaScript library for building user interfaces.',
#  'npm/cli\nThe package manager for JavaScript',
#  '',
#  'Features',
#  'Security',
#  'Team',
#  'Enterprise',
#  'Customer stories',
#  'The ReadME Project',
#  'Pricing',
#  'Resources',
#  'Roadmap',
#  'Developer API',
#  'Partners',
#  'Atom',
#  'Electron',
#  'GitHub Desktop',
#  'Docs',
#  'Community Forum',
#  'Professional Services',
#  'Skills',
#  'Status',
#  'Contact GitHub',
#  'About',
#  'Blog',
#  'Careers',
#  'Press',
#  'Inclusion',
#  'Social Impact',
#  'Shop',
#  'GitHub on Twitter',
#  'GitHub on Facebook',
#  'GitHub on YouTube',
#  'GitHub on LinkedIn',
#  'GitHub’s organization on GitHub',
#  'Terms',
#  'Privacy',
#  'Site Map',
#  'What is Git?',
#  '',
#  '',
#  'Skip to content',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Team',
#  'Enterprise',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Marketplace',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Sign in',
#  'Sign up',
#  '',
#  '',
#  '',
#  'Code',
#  'Collaborate',
#  'Develop',
#  'Automate',
#  'Secure',
#  'Community',
#  '',
#  'Sign up for GitHub',
#  '',
#  '',
#  'Create a new organization for free',
#  'GitHub Mobile',
#  '',
#  '',
#  'GitHub Desktop',
#  'GitHub CLI',
#  'Learn more about GitHub Codespaces',
#  'Learn more about GitHub Copilot',
#  'Learn more about GitHub Actions',
#  '',
#  'Learn more about Dependabot',
#  'Learn more about advanced security',
#  'Learn how to get started with Discussions',
#  '',
#  'Sign up for GitHub',
#  'Contact Sales',
#  'tensorflow/tensorflow\nAn Open Source Machine Learning Framework for Everyone',
#  'Build blazing fast, modern apps and websites with React',
#  '',
#  'rust-lang/rust\nEmpowering everyone to build reliable and efficient software.',
#  'flutter/flutter\nFlutter makes it easy and fast to build beautiful apps for mobile and beyond.',
#  '',
#  'apple/swift\nThe Swift Programming Language',
#  'ansible/ansible\nAnsible is a radically simple IT automation platform.',
#  '',
#  'ohmyzsh/ohmyzsh\n🙃 A delightful community-driven framework for managing your zsh configuration.',
#  'facebook/react\nA declarative, efficient, and flexible JavaScript library for building user interfaces.',
#  'npm/cli\nThe package manager for JavaScript',
#  '',
#  'Features',
#  'Security',
#  'Team',
#  'Enterprise',
#  'Customer stories',
#  'The ReadME Project',
#  'Pricing',
#  'Resources',
#  'Roadmap',
#  'Developer API',
#  'Partners',
#  'Atom',
#  'Electron',
#  'GitHub Desktop',
#  'Docs',
#  'Community Forum',
#  'Professional Services',
#  'Skills',
#  'Status',
#  'Contact GitHub',
#  'About',
#  'Blog',
#  'Careers',
#  'Press',
#  'Inclusion',
#  'Social Impact',
#  'Shop',
#  'GitHub on Twitter',
#  'GitHub on Facebook',
#  'GitHub on YouTube',
#  'GitHub on LinkedIn',
#  'GitHub’s organization on GitHub',
#  'Terms',
#  'Privacy',
#  'Site Map',
#  'What is Git?',
#  '',
#  '',
#  'Skip to content',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Team',
#  'Enterprise',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Marketplace',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Sign in',
#  'Sign up',
#  '',
#  '',
#  '',
#  'Code',
#  'Collaborate',
#  'Develop',
#  'Automate',
#  'Secure',
#  'Community',
#  '',
#  'Sign up for GitHub',
#  '',
#  '',
#  'Create a new organization for free',
#  'GitHub Mobile',
#  '',
#  '',
#  'GitHub Desktop',
#  'GitHub CLI',
#  'Learn more about GitHub Codespaces',
#  'Learn more about GitHub Copilot',
#  'Learn more about GitHub Actions',
#  '',
#  'Learn more about Dependabot',
#  'Learn more about advanced security',
#  'Learn how to get started with Discussions',
#  '',
#  'Sign up for GitHub',
#  'Contact Sales',
#  'tensorflow/tensorflow\nAn Open Source Machine Learning Framework for Everyone',
#  'Build blazing fast, modern apps and websites with React',
#  '',
#  'rust-lang/rust\nEmpowering everyone to build reliable and efficient software.',
#  'flutter/flutter\nFlutter makes it easy and fast to build beautiful apps for mobile and beyond.',
#  '',
#  'apple/swift\nThe Swift Programming Language',
#  'ansible/ansible\nAnsible is a radically simple IT automation platform.',
#  '',
#  'ohmyzsh/ohmyzsh\n🙃 A delightful community-driven framework for managing your zsh configuration.',
#  'facebook/react\nA declarative, efficient, and flexible JavaScript library for building user interfaces.',
#  'npm/cli\nThe package manager for JavaScript',
#  '',
#  'Features',
#  'Security',
#  'Team',
#  'Enterprise',
#  'Customer stories',
#  'The ReadME Project',
#  'Pricing',
#  'Resources',
#  'Roadmap',
#  'Developer API',
#  'Partners',
#  'Atom',
#  'Electron',
#  'GitHub Desktop',
#  'Docs',
#  'Community Forum',
#  'Professional Services',
#  'Skills',
#  'Status',
#  'Contact GitHub',
#  'About',
#  'Blog',
#  'Careers',
#  'Press',
#  'Inclusion',
#  'Social Impact',
#  'Shop',
#  'GitHub on Twitter',
#  'GitHub on Facebook',
#  'GitHub on YouTube',
#  'GitHub on LinkedIn',
#  'GitHub’s organization on GitHub',
#  'Terms',
#  'Privacy',
#  'Site Map',
#  'What is Git?',
#  '',
#  '',
#  'Skip to content',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Team',
#  'Enterprise',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Marketplace',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Sign in',
#  'Sign up',
#  ...]

# %%
description_tags=[]
for i in range(10):
    for j in driver.find_elements_by_xpath("//p[@class='col-9 d-inline-block color-text-secondary mb-2 pr-4']"):
        description_tags.append(j.text)
    time.sleep(5)
description_tags
# Out:
# []

# %%
count_tags=[]
for i in range(10):
    for j in driver.find_elements_by_xpath("//a"):
        count_tags.append(j.text)
    time.sleep(5)
count_tags
# Out:
# ['Skip to content',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Team',
#  'Enterprise',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Marketplace',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Sign in',
#  'Sign up',
#  '',
#  '',
#  '',
#  'Code',
#  'Collaborate',
#  'Develop',
#  'Automate',
#  'Secure',
#  'Community',
#  '',
#  'Sign up for GitHub',
#  '',
#  '',
#  'Create a new organization for free',
#  'GitHub Mobile',
#  '',
#  '',
#  'GitHub Desktop',
#  'GitHub CLI',
#  'Learn more about GitHub Codespaces',
#  'Learn more about GitHub Copilot',
#  'Learn more about GitHub Actions',
#  '',
#  'Learn more about Dependabot',
#  'Learn more about advanced security',
#  'Learn how to get started with Discussions',
#  '',
#  'Sign up for GitHub',
#  'Contact Sales',
#  'tensorflow/tensorflow\nAn Open Source Machine Learning Framework for Everyone',
#  'Build blazing fast, modern apps and websites with React',
#  '',
#  'rust-lang/rust\nEmpowering everyone to build reliable and efficient software.',
#  'flutter/flutter\nFlutter makes it easy and fast to build beautiful apps for mobile and beyond.',
#  '',
#  'apple/swift\nThe Swift Programming Language',
#  'ansible/ansible\nAnsible is a radically simple IT automation platform.',
#  '',
#  'ohmyzsh/ohmyzsh\n🙃 A delightful community-driven framework for managing your zsh configuration.',
#  'facebook/react\nA declarative, efficient, and flexible JavaScript library for building user interfaces.',
#  'npm/cli\nThe package manager for JavaScript',
#  '',
#  'Features',
#  'Security',
#  'Team',
#  'Enterprise',
#  'Customer stories',
#  'The ReadME Project',
#  'Pricing',
#  'Resources',
#  'Roadmap',
#  'Developer API',
#  'Partners',
#  'Atom',
#  'Electron',
#  'GitHub Desktop',
#  'Docs',
#  'Community Forum',
#  'Professional Services',
#  'Skills',
#  'Status',
#  'Contact GitHub',
#  'About',
#  'Blog',
#  'Careers',
#  'Press',
#  'Inclusion',
#  'Social Impact',
#  'Shop',
#  'GitHub on Twitter',
#  'GitHub on Facebook',
#  'GitHub on YouTube',
#  'GitHub on LinkedIn',
#  'GitHub’s organization on GitHub',
#  'Terms',
#  'Privacy',
#  'Site Map',
#  'What is Git?',
#  '',
#  '',
#  'Skip to content',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Team',
#  'Enterprise',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Marketplace',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Sign in',
#  'Sign up',
#  '',
#  '',
#  '',
#  'Code',
#  'Collaborate',
#  'Develop',
#  'Automate',
#  'Secure',
#  'Community',
#  '',
#  'Sign up for GitHub',
#  '',
#  '',
#  'Create a new organization for free',
#  'GitHub Mobile',
#  '',
#  '',
#  'GitHub Desktop',
#  'GitHub CLI',
#  'Learn more about GitHub Codespaces',
#  'Learn more about GitHub Copilot',
#  'Learn more about GitHub Actions',
#  '',
#  'Learn more about Dependabot',
#  'Learn more about advanced security',
#  'Learn how to get started with Discussions',
#  '',
#  'Sign up for GitHub',
#  'Contact Sales',
#  'tensorflow/tensorflow\nAn Open Source Machine Learning Framework for Everyone',
#  'Build blazing fast, modern apps and websites with React',
#  '',
#  'rust-lang/rust\nEmpowering everyone to build reliable and efficient software.',
#  'flutter/flutter\nFlutter makes it easy and fast to build beautiful apps for mobile and beyond.',
#  '',
#  'apple/swift\nThe Swift Programming Language',
#  'ansible/ansible\nAnsible is a radically simple IT automation platform.',
#  '',
#  'ohmyzsh/ohmyzsh\n🙃 A delightful community-driven framework for managing your zsh configuration.',
#  'facebook/react\nA declarative, efficient, and flexible JavaScript library for building user interfaces.',
#  'npm/cli\nThe package manager for JavaScript',
#  '',
#  'Features',
#  'Security',
#  'Team',
#  'Enterprise',
#  'Customer stories',
#  'The ReadME Project',
#  'Pricing',
#  'Resources',
#  'Roadmap',
#  'Developer API',
#  'Partners',
#  'Atom',
#  'Electron',
#  'GitHub Desktop',
#  'Docs',
#  'Community Forum',
#  'Professional Services',
#  'Skills',
#  'Status',
#  'Contact GitHub',
#  'About',
#  'Blog',
#  'Careers',
#  'Press',
#  'Inclusion',
#  'Social Impact',
#  'Shop',
#  'GitHub on Twitter',
#  'GitHub on Facebook',
#  'GitHub on YouTube',
#  'GitHub on LinkedIn',
#  'GitHub’s organization on GitHub',
#  'Terms',
#  'Privacy',
#  'Site Map',
#  'What is Git?',
#  '',
#  '',
#  'Skip to content',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Team',
#  'Enterprise',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Marketplace',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Sign in',
#  'Sign up',
#  '',
#  '',
#  '',
#  'Code',
#  'Collaborate',
#  'Develop',
#  'Automate',
#  'Secure',
#  'Community',
#  '',
#  'Sign up for GitHub',
#  '',
#  '',
#  'Create a new organization for free',
#  'GitHub Mobile',
#  '',
#  '',
#  'GitHub Desktop',
#  'GitHub CLI',
#  'Learn more about GitHub Codespaces',
#  'Learn more about GitHub Copilot',
#  'Learn more about GitHub Actions',
#  '',
#  'Learn more about Dependabot',
#  'Learn more about advanced security',
#  'Learn how to get started with Discussions',
#  '',
#  'Sign up for GitHub',
#  'Contact Sales',
#  'tensorflow/tensorflow\nAn Open Source Machine Learning Framework for Everyone',
#  'Build blazing fast, modern apps and websites with React',
#  '',
#  'rust-lang/rust\nEmpowering everyone to build reliable and efficient software.',
#  'flutter/flutter\nFlutter makes it easy and fast to build beautiful apps for mobile and beyond.',
#  '',
#  'apple/swift\nThe Swift Programming Language',
#  'ansible/ansible\nAnsible is a radically simple IT automation platform.',
#  '',
#  'ohmyzsh/ohmyzsh\n🙃 A delightful community-driven framework for managing your zsh configuration.',
#  'facebook/react\nA declarative, efficient, and flexible JavaScript library for building user interfaces.',
#  'npm/cli\nThe package manager for JavaScript',
#  '',
#  'Features',
#  'Security',
#  'Team',
#  'Enterprise',
#  'Customer stories',
#  'The ReadME Project',
#  'Pricing',
#  'Resources',
#  'Roadmap',
#  'Developer API',
#  'Partners',
#  'Atom',
#  'Electron',
#  'GitHub Desktop',
#  'Docs',
#  'Community Forum',
#  'Professional Services',
#  'Skills',
#  'Status',
#  'Contact GitHub',
#  'About',
#  'Blog',
#  'Careers',
#  'Press',
#  'Inclusion',
#  'Social Impact',
#  'Shop',
#  'GitHub on Twitter',
#  'GitHub on Facebook',
#  'GitHub on YouTube',
#  'GitHub on LinkedIn',
#  'GitHub’s organization on GitHub',
#  'Terms',
#  'Privacy',
#  'Site Map',
#  'What is Git?',
#  '',
#  '',
#  'Skip to content',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Team',
#  'Enterprise',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Marketplace',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Sign in',
#  'Sign up',
#  '',
#  '',
#  '',
#  'Code',
#  'Collaborate',
#  'Develop',
#  'Automate',
#  'Secure',
#  'Community',
#  '',
#  'Sign up for GitHub',
#  '',
#  '',
#  'Create a new organization for free',
#  'GitHub Mobile',
#  '',
#  '',
#  'GitHub Desktop',
#  'GitHub CLI',
#  'Learn more about GitHub Codespaces',
#  'Learn more about GitHub Copilot',
#  'Learn more about GitHub Actions',
#  '',
#  'Learn more about Dependabot',
#  'Learn more about advanced security',
#  'Learn how to get started with Discussions',
#  '',
#  'Sign up for GitHub',
#  'Contact Sales',
#  'tensorflow/tensorflow\nAn Open Source Machine Learning Framework for Everyone',
#  'Build blazing fast, modern apps and websites with React',
#  '',
#  'rust-lang/rust\nEmpowering everyone to build reliable and efficient software.',
#  'flutter/flutter\nFlutter makes it easy and fast to build beautiful apps for mobile and beyond.',
#  '',
#  'apple/swift\nThe Swift Programming Language',
#  'ansible/ansible\nAnsible is a radically simple IT automation platform.',
#  '',
#  'ohmyzsh/ohmyzsh\n🙃 A delightful community-driven framework for managing your zsh configuration.',
#  'facebook/react\nA declarative, efficient, and flexible JavaScript library for building user interfaces.',
#  'npm/cli\nThe package manager for JavaScript',
#  '',
#  'Features',
#  'Security',
#  'Team',
#  'Enterprise',
#  'Customer stories',
#  'The ReadME Project',
#  'Pricing',
#  'Resources',
#  'Roadmap',
#  'Developer API',
#  'Partners',
#  'Atom',
#  'Electron',
#  'GitHub Desktop',
#  'Docs',
#  'Community Forum',
#  'Professional Services',
#  'Skills',
#  'Status',
#  'Contact GitHub',
#  'About',
#  'Blog',
#  'Careers',
#  'Press',
#  'Inclusion',
#  'Social Impact',
#  'Shop',
#  'GitHub on Twitter',
#  'GitHub on Facebook',
#  'GitHub on YouTube',
#  'GitHub on LinkedIn',
#  'GitHub’s organization on GitHub',
#  'Terms',
#  'Privacy',
#  'Site Map',
#  'What is Git?',
#  '',
#  '',
#  'Skip to content',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Team',
#  'Enterprise',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Marketplace',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Sign in',
#  'Sign up',
#  '',
#  '',
#  '',
#  'Code',
#  'Collaborate',
#  'Develop',
#  'Automate',
#  'Secure',
#  'Community',
#  '',
#  'Sign up for GitHub',
#  '',
#  '',
#  'Create a new organization for free',
#  'GitHub Mobile',
#  '',
#  '',
#  'GitHub Desktop',
#  'GitHub CLI',
#  'Learn more about GitHub Codespaces',
#  'Learn more about GitHub Copilot',
#  'Learn more about GitHub Actions',
#  '',
#  'Learn more about Dependabot',
#  'Learn more about advanced security',
#  'Learn how to get started with Discussions',
#  '',
#  'Sign up for GitHub',
#  'Contact Sales',
#  'tensorflow/tensorflow\nAn Open Source Machine Learning Framework for Everyone',
#  'Build blazing fast, modern apps and websites with React',
#  '',
#  'rust-lang/rust\nEmpowering everyone to build reliable and efficient software.',
#  'flutter/flutter\nFlutter makes it easy and fast to build beautiful apps for mobile and beyond.',
#  '',
#  'apple/swift\nThe Swift Programming Language',
#  'ansible/ansible\nAnsible is a radically simple IT automation platform.',
#  '',
#  'ohmyzsh/ohmyzsh\n🙃 A delightful community-driven framework for managing your zsh configuration.',
#  'facebook/react\nA declarative, efficient, and flexible JavaScript library for building user interfaces.',
#  'npm/cli\nThe package manager for JavaScript',
#  '',
#  'Features',
#  'Security',
#  'Team',
#  'Enterprise',
#  'Customer stories',
#  'The ReadME Project',
#  'Pricing',
#  'Resources',
#  'Roadmap',
#  'Developer API',
#  'Partners',
#  'Atom',
#  'Electron',
#  'GitHub Desktop',
#  'Docs',
#  'Community Forum',
#  'Professional Services',
#  'Skills',
#  'Status',
#  'Contact GitHub',
#  'About',
#  'Blog',
#  'Careers',
#  'Press',
#  'Inclusion',
#  'Social Impact',
#  'Shop',
#  'GitHub on Twitter',
#  'GitHub on Facebook',
#  'GitHub on YouTube',
#  'GitHub on LinkedIn',
#  'GitHub’s organization on GitHub',
#  'Terms',
#  'Privacy',
#  'Site Map',
#  'What is Git?',
#  '',
#  '',
#  'Skip to content',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Team',
#  'Enterprise',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Marketplace',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Sign in',
#  'Sign up',
#  '',
#  '',
#  '',
#  'Code',
#  'Collaborate',
#  'Develop',
#  'Automate',
#  'Secure',
#  'Community',
#  '',
#  'Sign up for GitHub',
#  '',
#  '',
#  'Create a new organization for free',
#  'GitHub Mobile',
#  '',
#  '',
#  'GitHub Desktop',
#  'GitHub CLI',
#  'Learn more about GitHub Codespaces',
#  'Learn more about GitHub Copilot',
#  'Learn more about GitHub Actions',
#  '',
#  'Learn more about Dependabot',
#  'Learn more about advanced security',
#  'Learn how to get started with Discussions',
#  '',
#  'Sign up for GitHub',
#  'Contact Sales',
#  'tensorflow/tensorflow\nAn Open Source Machine Learning Framework for Everyone',
#  'Build blazing fast, modern apps and websites with React',
#  '',
#  'rust-lang/rust\nEmpowering everyone to build reliable and efficient software.',
#  'flutter/flutter\nFlutter makes it easy and fast to build beautiful apps for mobile and beyond.',
#  '',
#  'apple/swift\nThe Swift Programming Language',
#  'ansible/ansible\nAnsible is a radically simple IT automation platform.',
#  '',
#  'ohmyzsh/ohmyzsh\n🙃 A delightful community-driven framework for managing your zsh configuration.',
#  'facebook/react\nA declarative, efficient, and flexible JavaScript library for building user interfaces.',
#  'npm/cli\nThe package manager for JavaScript',
#  '',
#  'Features',
#  'Security',
#  'Team',
#  'Enterprise',
#  'Customer stories',
#  'The ReadME Project',
#  'Pricing',
#  'Resources',
#  'Roadmap',
#  'Developer API',
#  'Partners',
#  'Atom',
#  'Electron',
#  'GitHub Desktop',
#  'Docs',
#  'Community Forum',
#  'Professional Services',
#  'Skills',
#  'Status',
#  'Contact GitHub',
#  'About',
#  'Blog',
#  'Careers',
#  'Press',
#  'Inclusion',
#  'Social Impact',
#  'Shop',
#  'GitHub on Twitter',
#  'GitHub on Facebook',
#  'GitHub on YouTube',
#  'GitHub on LinkedIn',
#  'GitHub’s organization on GitHub',
#  'Terms',
#  'Privacy',
#  'Site Map',
#  'What is Git?',
#  '',
#  '',
#  'Skip to content',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Team',
#  'Enterprise',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Marketplace',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Sign in',
#  'Sign up',
#  '',
#  '',
#  '',
#  'Code',
#  'Collaborate',
#  'Develop',
#  'Automate',
#  'Secure',
#  'Community',
#  '',
#  'Sign up for GitHub',
#  '',
#  '',
#  'Create a new organization for free',
#  'GitHub Mobile',
#  '',
#  '',
#  'GitHub Desktop',
#  'GitHub CLI',
#  'Learn more about GitHub Codespaces',
#  'Learn more about GitHub Copilot',
#  'Learn more about GitHub Actions',
#  '',
#  'Learn more about Dependabot',
#  'Learn more about advanced security',
#  'Learn how to get started with Discussions',
#  '',
#  'Sign up for GitHub',
#  'Contact Sales',
#  'tensorflow/tensorflow\nAn Open Source Machine Learning Framework for Everyone',
#  'Build blazing fast, modern apps and websites with React',
#  '',
#  'rust-lang/rust\nEmpowering everyone to build reliable and efficient software.',
#  'flutter/flutter\nFlutter makes it easy and fast to build beautiful apps for mobile and beyond.',
#  '',
#  'apple/swift\nThe Swift Programming Language',
#  'ansible/ansible\nAnsible is a radically simple IT automation platform.',
#  '',
#  'ohmyzsh/ohmyzsh\n🙃 A delightful community-driven framework for managing your zsh configuration.',
#  'facebook/react\nA declarative, efficient, and flexible JavaScript library for building user interfaces.',
#  'npm/cli\nThe package manager for JavaScript',
#  '',
#  'Features',
#  'Security',
#  'Team',
#  'Enterprise',
#  'Customer stories',
#  'The ReadME Project',
#  'Pricing',
#  'Resources',
#  'Roadmap',
#  'Developer API',
#  'Partners',
#  'Atom',
#  'Electron',
#  'GitHub Desktop',
#  'Docs',
#  'Community Forum',
#  'Professional Services',
#  'Skills',
#  'Status',
#  'Contact GitHub',
#  'About',
#  'Blog',
#  'Careers',
#  'Press',
#  'Inclusion',
#  'Social Impact',
#  'Shop',
#  'GitHub on Twitter',
#  'GitHub on Facebook',
#  'GitHub on YouTube',
#  'GitHub on LinkedIn',
#  'GitHub’s organization on GitHub',
#  'Terms',
#  'Privacy',
#  'Site Map',
#  'What is Git?',
#  '',
#  '',
#  'Skip to content',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Team',
#  'Enterprise',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Marketplace',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Sign in',
#  'Sign up',
#  '',
#  '',
#  '',
#  'Code',
#  'Collaborate',
#  'Develop',
#  'Automate',
#  'Secure',
#  'Community',
#  '',
#  'Sign up for GitHub',
#  '',
#  '',
#  'Create a new organization for free',
#  'GitHub Mobile',
#  '',
#  '',
#  'GitHub Desktop',
#  'GitHub CLI',
#  'Learn more about GitHub Codespaces',
#  'Learn more about GitHub Copilot',
#  'Learn more about GitHub Actions',
#  '',
#  'Learn more about Dependabot',
#  'Learn more about advanced security',
#  'Learn how to get started with Discussions',
#  '',
#  'Sign up for GitHub',
#  'Contact Sales',
#  'tensorflow/tensorflow\nAn Open Source Machine Learning Framework for Everyone',
#  'Build blazing fast, modern apps and websites with React',
#  '',
#  'rust-lang/rust\nEmpowering everyone to build reliable and efficient software.',
#  'flutter/flutter\nFlutter makes it easy and fast to build beautiful apps for mobile and beyond.',
#  '',
#  'apple/swift\nThe Swift Programming Language',
#  'ansible/ansible\nAnsible is a radically simple IT automation platform.',
#  '',
#  'ohmyzsh/ohmyzsh\n🙃 A delightful community-driven framework for managing your zsh configuration.',
#  'facebook/react\nA declarative, efficient, and flexible JavaScript library for building user interfaces.',
#  'npm/cli\nThe package manager for JavaScript',
#  '',
#  'Features',
#  'Security',
#  'Team',
#  'Enterprise',
#  'Customer stories',
#  'The ReadME Project',
#  'Pricing',
#  'Resources',
#  'Roadmap',
#  'Developer API',
#  'Partners',
#  'Atom',
#  'Electron',
#  'GitHub Desktop',
#  'Docs',
#  'Community Forum',
#  'Professional Services',
#  'Skills',
#  'Status',
#  'Contact GitHub',
#  'About',
#  'Blog',
#  'Careers',
#  'Press',
#  'Inclusion',
#  'Social Impact',
#  'Shop',
#  'GitHub on Twitter',
#  'GitHub on Facebook',
#  'GitHub on YouTube',
#  'GitHub on LinkedIn',
#  'GitHub’s organization on GitHub',
#  'Terms',
#  'Privacy',
#  'Site Map',
#  'What is Git?',
#  '',
#  '',
#  'Skip to content',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Team',
#  'Enterprise',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Marketplace',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Sign in',
#  'Sign up',
#  ...]

# %%
langauge_tags=[]
for i in range(10):
    for j in driver.find_elements_by_xpath("//span[@class='text-normal']"):
        langauge_tags.append(j.text)
    time.sleep(5)
langauge_tags
# Out:
# []

# %%
#Creating dataframe
df=pd.DataFrame({})

df['repositorytitle_tags']=repositorytitle_tags[100:]

df['count_tags']=count_tags[100:]

# %%
df
# Out:
#      repositorytitle_tags      count_tags
# 0                  Status          Status
# 1          Contact GitHub  Contact GitHub
# 2                   About           About
# 3                    Blog            Blog
# 4                 Careers         Careers
# ...                   ...             ...
# 1095              Privacy         Privacy
# 1096             Site Map        Site Map
# 1097         What is Git?    What is Git?
# 1098
# 1099
#
# [1100 rows x 2 columns]
